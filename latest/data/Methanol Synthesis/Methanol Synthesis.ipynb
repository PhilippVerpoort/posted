# %% [markdown]
# # Methanol Synthesis

# %% [markdown]
# This dataset contains techno-economic data on methanol synthesis plants without reforming (from H₂ and CO₂).

# %%
# Dependencies.
from IPython.display import HTML, Markdown

import numpy as np
import pandas as pd
pd.options.plotting.backend = "plotly"
import plotly.express as px
from plotly.subplots import make_subplots

from posted import TEDF


# Set variable of TEDF.
var = "Tech|Methanol Synthesis"

# Loading the TEDF.
tedf = TEDF.load(var)

# Define units to use.
units = {
    "CAPEX": "EUR_2024",
    "OPEX Fixed": "EUR_2024/yr",
    "OPEX Variable": "EUR_2024",
    "Output Capacity|Methanol": "t_MeOH/year",
    "Output|Methanol": "t_MeOH",
}

# %% [markdown]
# ## Aggregated parameters

# %% [markdown]
# All data in this dataset can be aggregated via the NOSLAG workflow, which yields the following parameters:

# %%
aggregated = tedf.aggregate(units=units, append_references=True)

display(
    aggregated
    .set_index(["variable", "unit"])
    .T
    .map(lambda x: float(f"{x:.3g}") if not pd.isnull(x) else x)
    .fillna("")
)
# Out:
# /home/runner/work/posted/posted/posted/noslag/tedf.py:297: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = self._df.replace("", np.nan)
# variable    CAPEX Emissions|CO2 Input|Captured CO2 Input|Electricity  \
# unit     EUR_2024        kg CO2                  t               MWh
# value       417.0          56.5               1.43             0.503
#
# variable Input|Hydrogen Lifetime           OCF  OPEX Fixed OPEX Variable  \
# unit               t_H2     year dimensionless EUR_2024/yr      EUR_2024
# value             0.196     20.0         0.913        20.9          20.8
#
# variable Output Capacity|Methanol Output|Heat Output|Methanol
# unit                  t_MeOH/year         MWh          t_MeOH
# value                         1.0        0.58             1.0

# %% [markdown]
# ## Raw data

# %%
Markdown(f"""
The table below contains the raw data contained in this dataset. The raw data has not be normalised or harmonised 
in any way and should closely resemble the data as it is reported by the respective sources. You can also find 
this data in the GitHub repo in this file:
{link_public_github(var)}
""")
# Out:
# The table below contains the raw data contained in this dataset. The raw data has not be normalised or harmonised
# in any way and should closely resemble the data as it is reported by the respective sources. You can also find
# this data in the GitHub repo in this file:
# <a href="https://github.com/PhilippVerpoort/posted/blob/main/posted/database/tedfs/Tech/Methanol Synthesis.csv">posted/database/tedfs/Tech/Methanol Synthesis.csv</a>

# %%
tedf.edit_data()
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_86f7dbd7_a445_40f5_be91_490a26ab75c4">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.7.3 from the internet...
#         (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_86f7dbd7_a445_40f5_be91_490a26ab75c4:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"Perez-Fortes-2016\", \"Table 3\", \"#\", \"2014\", \"CAPEX\", \"Output Capacity|Methanol\", \"496.5\", \"\", \"EUR_2014\", \"1\", \"t_MeOH/year\", \"\"], [\"Nyari-2020\", \"Table A4\", \"#\", \"2018\", \"CAPEX\", \"Output Capacity|Methanol\", \"209.5\", \"\", \"EUR_2018\", \"1\", \"t_MeOH/year\", \"Calculated manually from: CAPEX = PEC * 6.32, (as stated in the paper) and 5kt/d plant.\"], [\"Bos-2020\", \"Table S8\", \"#\", \"2020\", \"CAPEX\", \"Output Capacity|Methanol\", \"169\", \"\", \"EUR_2020\", \"1\", \"t_MeOH/year\", \"Calculated manually from: CAPEX = PEC * 6.32, (as stated in the paper) and 5kt/d plant. No cost basis cited, assumed to be year of publication.\"], [\"Grahn-2022\", \"Table 3\", \"#\", \"2025\", \"CAPEX\", \"Output Capacity|Methanol\", \"700\", \"\", \"EUR_2019\", \"1\", \"kW_MeOH_LHV\", \"\"], [\"Grahn-2022\", \"Table 3\", \"#\", \"2040\", \"CAPEX\", \"Output Capacity|Methanol\", \"300\", \"\", \"EUR_2019\", \"1\", \"kW_MeOH_LHV\", \"\"], [\"Perez-Fortes-2016\", \"Table 3\", \"#\", \"2014\", \"OPEX Fixed\", \"Output Capacity|Methanol\", \"11\", \"\", \"MEUR_2014/a\", \"440\", \"kt_MeOH/year\", \"\"], [\"Nyari-2020\", \"Table 5\", \"Admin\", \"2018\", \"OPEX Fixed\", \"Output Capacity|Methanol\", \"0.94\", \"\", \"EUR_2018/a\", \"1\", \"t_MeOH/year\", \"Reported as OPEX Fixed relative (0.45%), manually converted to OPEX FIxed. Nyari misquotes the result from Collodi (2017). admin + overhead component = 30% * (direct_labour + om). Here we have only the 30% * om = 0.45% of TPC .\"], [\"Nyari-2020\", \"Table 5\", \"Operation &amp; Maintenance\", \"2018\", \"OPEX Fixed\", \"Output Capacity|Methanol\", \"3.14\", \"\", \"EUR_2018/a\", \"1\", \"t_MeOH/year\", \"Reported as OPEX Fixed relative (1.5%), manually converted to OPEX Fixed. Operation and maintenance. Percentage of the total plant cost (TPC)\"], [\"Nyari-2020\", \"Table 5\", \"Tax\", \"2018\", \"OPEX Fixed\", \"Output Capacity|Methanol\", \"2.10\", \"\", \"EUR_2018/a\", \"1\", \"t_MeOH/year\", \"Reported as OPEX Fixed relative (1%), manually converted to OPEX Fixed. In fact, this comprises insurance + taxes. Percentage of the total plant cost (TPC)\"], [\"Grahn-2022\", \"Table 7\", \"#\", \"2025\", \"OPEX Fixed Relative\", \"\", \"4\", \"\", \"percent\", \"\", \"\", \"\"], [\"Grahn-2022\", \"Table 7\", \"#\", \"2040\", \"OPEX Fixed Relative\", \"\", \"4\", \"\", \"percent\", \"\", \"\", \"\"], [\"Perez-Fortes-2016\", \"Table 3, Figure 6\", \"#\", \"2014\", \"OPEX Variable\", \"Output|Methanol\", \"11.6\", \"\", \"MEUR_2014\", \"402\", \"kt_MeOH\", \"Utilities and consumables ammount to 4.1% of variable operating costs (Fig. 6). 4.1% of 283 MEUR is 11.6 MEUR (see Table 3). A plant of capacity 440 kt/a produces 402 kt in 8000 full-load hours.\"], [\"Nyari-2020\", \"Table 5\", \"Labour\", \"2018\", \"OPEX Variable\", \"Output|Methanol\", \"2.01\", \"\", \"EUR_2018\", \"1\", \"t_MeOH\", \"Nyari misquotes the result from Collodi (2017). There are in fact 61 workers * 60 000 mean salary =3.66MEUR/a. Production of 5000 MTPD =&gt; 1.825e6 t/a.Although it is quoted as a fixed OPEX cost, we give this as a vopex cost, since it is in EUR/t \"], [\"Nyari-2020\", \"Table 5\", \"Admin\", \"2018\", \"OPEX Variable\", \"Output|Methanol\", \"0.6\", \"\", \"EUR_2018\", \"1\", \"t_MeOH\", \"Nyari misquotes the result from Collodi (2017). admin + overhead component = 30% * (direct_labour + om). Here we have only the 30% * direct labour.Production of 5000 MTPD =&gt; 1.825e6 t/a. Although it is quoted as a fixed OPEX cost, we give this as a vopex cost, since it is in EUR/t\"], [\"Bazzanella-2017\", \"Section 4.4.3\", \"#\", \"2017\", \"Input|Electricity\", \"Output|Methanol\", \"1.5\", \"\", \"MWh\", \"1\", \"t_MeOH\", \"\"], [\"Soler-2022\", \"Table 3\", \"#\", \"2020\", \"Input|Electricity\", \"Output|Methanol\", \"1.07\", \"\", \"MJ\", \"1\", \"kg_MeOH\", \"Value based on JEC 2020\"], [\"Nyari-2020\", \"Table 6\", \"#\", \"2018\", \"Input|Elec ...
