# %% [markdown]
# # Fischer-Tropsch

# %% [markdown]
# This dataset contains techno-economic data on Fischer-Tropsch synthesis plants.

# %%
# Dependencies.
from IPython.display import HTML, Markdown

import numpy as np
import pandas as pd
pd.options.plotting.backend = "plotly"
import plotly.express as px
from plotly.subplots import make_subplots

from posted import TEDF


# Set variable of TEDF.
var = "Tech|Fischer-Tropsch"

# Loading the TEDF.
tedf = TEDF.load(var)

# Define units to use.
units = {
    "CAPEX": "EUR_2024",
    "OPEX Fixed": "EUR_2024/yr",
    "OPEX Variable": "EUR_2024",
    "Output Capacity|Fischer-Tropsch Fuel": "kW",
    "Output|Fischer-Tropsch Fuel": "MWh",
}

# %% [markdown]
# ## Aggregated parameters

# %% [markdown]
# All data in this dataset can be aggregated via the NOSLAG workflow, which yields the following parameters:

# %%
aggregated = tedf.aggregate(units=units, append_references=True)

display(
    aggregated
    .set_index(["variable", "unit"])
    .T
    .map(lambda x: float(f"{x:.3g}") if not pd.isnull(x) else x)
    .fillna("")
)
# Out:
# /home/runner/work/posted/posted/posted/noslag/_tedf.py:336: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = self._df.replace("", np.nan)
# variable    CAPEX Input|Electricity     Input|Hydrogen Lifetime  OPEX Fixed  \
# unit     EUR_2024                GJ percent MWh_H2_LHV     year EUR_2024/yr
# value      1000.0          0.000473                1.0     26.7        40.0
#
# variable Output Capacity|Fischer-Tropsch Fuel Output|Fischer-Tropsch Fuel
# unit                                       kW                         MWh
# value                                     1.0                      0.0073

# %% [markdown]
# ## Raw data

# %%
Markdown(f"""
The table below contains the raw data contained in this dataset. The raw data has not be normalised or harmonised 
in any way and should closely resemble the data as it is reported by the respective sources. You can also find 
this data in the GitHub repo in this file:
{link_public_github(var)}
""")
# Out:
# The table below contains the raw data contained in this dataset. The raw data has not be normalised or harmonised
# in any way and should closely resemble the data as it is reported by the respective sources. You can also find
# this data in the GitHub repo in this file:
# <a href="https://github.com/PhilippVerpoort/posted/blob/main/posted/database/tedfs/Tech/Fischer-Tropsch.csv">posted/database/tedfs/Tech/Fischer-Tropsch.csv</a>

# %%
tedf.edit_data()
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_c5aa08bc_3486_4a9c_a4cf_dcd968dc6bb8">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.7.3 from the internet...
#         (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_c5aa08bc_3486_4a9c_a4cf_dcd968dc6bb8:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {
#           "classes": ["display", "nowrap", "compact"],
#           "data_json": "[[\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2019\", \"CAPEX\", \"Output Capacity|Fischer-Tropsch Fuel\", \"890.0\", \"\", \"USD_2017\", \"1.0\", \"kW\", \"See \\\"Assumptions\\\" of the report. Given in kW_liquid\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2030\", \"CAPEX\", \"Output Capacity|Fischer-Tropsch Fuel\", \"760.0\", \"\", \"USD_2017\", \"1.0\", \"kW\", \"See \\\"Assumptions\\\" of the report. Given in kW_liquid\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2050\", \"CAPEX\", \"Output Capacity|Fischer-Tropsch Fuel\", \"565.0\", \"\", \"USD_2017\", \"1.0\", \"kW\", \"See \\\"Assumptions\\\" of the report. Given in kW_liquid. Stated to be long-term assumption, interpreted to be for 2050.\"], [\"Buchenberg-2023\", \" Table 1\", \"2020\", \"CAPEX\", \"Output Capacity|Fischer-Tropsch Fuel\", \"1011.0\", \"\", \"EUR_2017\", \"1.0\", \"kW\", \"Numbers taken from the IEA-FOH-2019 assumptions file\"], [\"Buchenberg-2023\", \" Table 1\", \"2030\", \"CAPEX\", \"Output Capacity|Fischer-Tropsch Fuel\", \"864.0\", \"\", \"EUR_2017\", \"1.0\", \"kW\", \"Numbers taken from the IEA-FOH-2019 assumptions file\"], [\"Buchenberg-2023\", \" Table 1\", \"2050\", \"CAPEX\", \"Output Capacity|Fischer-Tropsch Fuel\", \"642.0\", \"\", \"EUR_2017\", \"1.0\", \"kW\", \"Numbers taken from the IEA-FOH-2019 assumptions file\"], [\"Korberg-2021\", \" Table 1\", \"2030\", \"CAPEX\", \"Output Capacity|Fischer-Tropsch Fuel\", \"0.73\", \"\", \"MEUR_2021\", \"1.0\", \"MW\", \"\"], [\"Buchenberg-2023\", \" Table 1\", \"2023\", \"OPEX Fixed Relative\", \"\", \"4.0\", \"\", \"percent\", \"\", \"\", \"Numbers taken from the IEA-FOH-2019 assumptions file\"], [\"Korberg-2021\", \" Table 1\", \"2030\", \"OPEX Fixed Relative\", \"\", \"4.0\", \"\", \"percent\", \"\", \"\", \"\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2019\", \"OPEX Fixed Relative\", \"\", \"4.0\", \"\", \"percent\", \"\", \"\", \"See \\\"Assumptions\\\" of the report.\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2030\", \"OPEX Fixed Relative\", \"\", \"4.0\", \"\", \"percent\", \"\", \"\", \"See \\\"Assumptions\\\" of the report.\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2050\", \"OPEX Fixed Relative\", \"\", \"4.0\", \"\", \"percent\", \"\", \"\", \"See \\\"Assumptions\\\" of the report.\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2019\", \"Lifetime\", \"\", \"30.0\", \"\", \"year\", \"\", \"\", \"See \\\"Assumptions\\\" of the report.\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2030\", \"Lifetime\", \"\", \"30.0\", \"\", \"year\", \"\", \"\", \"See \\\"Assumptions\\\" of the report.\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2050\", \"Lifetime\", \"\", \"30.0\", \"\", \"year\", \"\", \"\", \"See \\\"Assumptions\\\" of the report.\"], [\"Buchenberg-2023\", \" Table 1\", \"2023\", \"Lifetime\", \"\", \"25.0\", \"\", \"year\", \"\", \"\", \"Numbers taken from the IEA-FOH-2019 assumptions file, but incorrectly reported\"], [\"Korberg-2021\", \" Table 1\", \"2030\", \"Lifetime\", \"\", \"25.0\", \"\", \"year\", \"\", \"\", \"\"], [\"Korberg-2021\", \" Table 1\", \"2030\", \"Output|Fischer-Tropsch Fuel\", \"Input|Hydrogen\", \"0.73\", \"\", \"MJ\", \"1.0\", \"MJ_H2_LHV\", \"Given as a percentage in the source (73%)\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2019\", \"Input|Electricity\", \"Output|Fischer-Tropsch Fuel\", \"0.018\", \"\", \"GJ\", \"1.0\", \"GJ\", \"See \\\"Assumptions\\\" of the report.\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2030\", \"Input|Electricity\", \"Output|Fischer-Tropsch Fuel\", \"0.018\", \"\", \"GJ\", \"1.0\", \"GJ\", \"See \\\"Assumptions\\\" of the report.\"], [\"IEA-FOH-2019\", \"Assumptions file, Fischer-Tropsch table\", \"2050\", \"Input|Electricity\", \"Outp ...
