# %% [markdown]
# # Steel casting and hot rolling

# %% [markdown]
# This dataset contains techno-economic data on casting and hot-rolling processing of steel.

# %%
# Dependencies.
from IPython.display import HTML, Markdown

import numpy as np
import pandas as pd
pd.options.plotting.backend = "plotly"
import plotly.express as px

from posted import TEDF

# %% [markdown]
# ## Aggregated parameters

# %% [markdown]
# All data in the two datasets can be aggregated via the NOSLAG workflow, which yields the following parameters:

# %%
for t in ["Steel Casting", "Steel Hot Rolling"]:
    display(Markdown(f"### {t}"))
    display(
        TEDF.load(f"Tech|{t}").aggregate(append_references=True)
    )
# Out:
# ### Steel Casting
#                      variable        value       unit
# 0                       CAPEX    58.647525  MEUR_2024
# 1           Input|Electricity     0.033540         GJ
# 2                  Input|Heat     0.026000         GJ
# 3          Input|Steel Liquid  1032.000000         kg
# 4  Output Capacity|Steel Slab     1.000000       Mt/a
# 5           Output|Steel Slab     1.000000          t
# ### Steel Hot Rolling
#                                 variable        value       unit
# 0                                  CAPEX   145.490976  MEUR_2024
# 1                      Input|Electricity     0.339540         GJ
# 2                             Input|Heat     1.492994         GJ
# 3                       Input|Steel Slab  1052.600000         kg
# 4  Output Capacity|Steel Hot-rolled Coil     1.000000       Mt/a
# 5           Output|Steel Hot-rolled Coil     1.000000          t

# %% [markdown]
# ## Raw data

# %%
Markdown(f"""
The tables below contain the raw data contained in the two datasets. The raw data has not be normalised or harmonised 
in any way and should closely resemble the data as it is reported by the respective sources. You can also find 
this data in the GitHub repo in these two files:
{link_public_github('Tech|Steel Casting')} and {link_public_github('Tech|Steel Hot Rolling')}
""")
# Out:
# The tables below contain the raw data contained in the two datasets. The raw data has not be normalised or harmonised
# in any way and should closely resemble the data as it is reported by the respective sources. You can also find
# this data in the GitHub repo in these two files:
# <a href="https://github.com/PhilippVerpoort/posted/blob/main/posted/database/tedfs/Tech/Steel Casting.csv">posted/database/tedfs/Tech/Steel Casting.csv</a> and <a href="https://github.com/PhilippVerpoort/posted/blob/main/posted/database/tedfs/Tech/Steel Hot Rolling.csv">posted/database/tedfs/Tech/Steel Hot Rolling.csv</a>

# %%
for t in ["Steel Casting", "Steel Hot Rolling"]:
    display(Markdown(f"### {t}"))
    display(TEDF.load(f"Tech|{t}").edit_data())
# Out:
# ### Steel Casting
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ad8efd29_c2db_41c1_b4a9_7989f1bfdf7f" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_ad8efd29_c2db_41c1_b4a9_7989f1bfdf7f_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>source</th>
#       <th style="border:1px solid #ddd;padding:8px">source_detail</th>
#       <th style="border:1px solid #ddd;padding:8px">period</th>
#       <th style="border:1px solid #ddd;padding:8px">variable</th>
#       <th style="border:1px solid #ddd;padding:8px">reference_variable</th>
#       <th style="border:1px solid #ddd;padding:8px">value</th>
#       <th style="border:1px solid #ddd;padding:8px">uncertainty</th>
#       <th style="border:1px solid #ddd;padding:8px">unit</th>
#       <th style="border:1px solid #ddd;padding:8px">reference_value</th>
#       <th style="border:1px solid #ddd;padding:8px">reference_unit</th>
#       <th style="border:1px solid #ddd;padding:8px">comment</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Tables 1 and 5</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">CAPEX</td><td style="border:1px solid #ddd;padding:8px">Output Capacity|Steel Slab</td><td style="border:1px solid #ddd;padding:8px">195</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">MUSD_2010</td><td style="border:1px solid #ddd;padding:8px">4.3</td><td style="border:1px solid #ddd;padding:8px">Mt/a</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Table D-13</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Electricity</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Slab</td><td style="border:1px solid #ddd;padding:8px">10.3</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">kWh</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Table D-13</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Heat</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Slab</td><td style="border:1px solid #ddd;padding:8px">22</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">MJ</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px">Assuming 20MJ/Nm³ for caloric heating value of COG.</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Worrell-2007</td><td style="border:1px solid #ddd;padding:8px">Table 2.1.5</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Electricity</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Slab</td><td style="border:1px solid #ddd;padding:8px">0.03</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">GJ</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Worrell-2007</td><td style="border:1px solid #ddd;padding:8px">Table 2.1.5</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Heat</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Slab</td><td style="border:1px solid #ddd;padding:8px">0.03</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">GJ</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Table D-13</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Steel Liquid</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Slab</td><td style="border:
# None
# ### Steel Hot Rolling
# <!--| quarto-html-table-processing: none -->
# <table id="itables_e97a2f31_4e62_4170_9b02_45b69da95953" hidden="hidden">
#   <tbody>
#     <tr>
#       <td style="vertical-align:middle; text-align:left"><a href=https://itables.org/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:var(--itables-logo-paper,#d9d7fc)">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:var(--itables-logo-ink,#1a1366);stroke:var(--itables-logo-ink,#1a1366);">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#         Loading ITables v2.9.1 from the internet...
#         (need <a href=https://itables.org/troubleshooting.html>help</a>?)
#       </td>
#     </tr>
#   </tbody>
# </table>
# <div id="itables_e97a2f31_4e62_4170_9b02_45b69da95953_fallback"><table style="border-collapse:collapse"><thead>    <tr style="text-align: right;">
#       <th style="border:1px solid #ddd;padding:8px"><sup><noscript><span title="JavaScript not allowed. Please trust this notebook to get interactive tables.">🔒</span></noscript><a href=https://itables.org/fallbacks/static_preview.html title="ITables v2.9.1 static preview">ⓘ</a></sup>source</th>
#       <th style="border:1px solid #ddd;padding:8px">source_detail</th>
#       <th style="border:1px solid #ddd;padding:8px">period</th>
#       <th style="border:1px solid #ddd;padding:8px">variable</th>
#       <th style="border:1px solid #ddd;padding:8px">reference_variable</th>
#       <th style="border:1px solid #ddd;padding:8px">value</th>
#       <th style="border:1px solid #ddd;padding:8px">uncertainty</th>
#       <th style="border:1px solid #ddd;padding:8px">unit</th>
#       <th style="border:1px solid #ddd;padding:8px">reference_value</th>
#       <th style="border:1px solid #ddd;padding:8px">reference_unit</th>
#       <th style="border:1px solid #ddd;padding:8px">comment</th>
#     </tr></thead><tbody>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Tables 1 and 5</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">CAPEX</td><td style="border:1px solid #ddd;padding:8px">Output Capacity|Steel Hot-rolled Coil</td><td style="border:1px solid #ddd;padding:8px">450</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">MUSD_2010</td><td style="border:1px solid #ddd;padding:8px">4</td><td style="border:1px solid #ddd;padding:8px">Mt/a</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Table D-15</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Electricity</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Hot-rolled Coil</td><td style="border:1px solid #ddd;padding:8px">105.3</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">kWh</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Table D-15</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Heat</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Hot-rolled Coil</td><td style="border:1px solid #ddd;padding:8px">468.33</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">kWh</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px">Assuming 20MJ/Nm³ for caloric heating value of COG.</td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Worrell-2007</td><td style="border:1px solid #ddd;padding:8px">Table 2.1.5</td><td style="border:1px solid #ddd;padding:8px">2007</td><td style="border:1px solid #ddd;padding:8px">Input|Electricity</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Hot-rolled Coil</td><td style="border:1px solid #ddd;padding:8px">0.3</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">GJ</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">Worrell-2007</td><td style="border:1px solid #ddd;padding:8px">Table 2.1.5</td><td style="border:1px solid #ddd;padding:8px">2007</td><td style="border:1px solid #ddd;padding:8px">Input|Heat</td><td style="border:1px solid #ddd;padding:8px">Output|Steel Hot-rolled Coil</td><td style="border:1px solid #ddd;padding:8px">1.3</td><td style="border:1px solid #ddd;padding:8px"></td><td style="border:1px solid #ddd;padding:8px">GJ</td><td style="border:1px solid #ddd;padding:8px">1</td><td style="border:1px solid #ddd;padding:8px">t</td><td style="border:1px solid #ddd;padding:8px"></td></tr>
# <tr><td style="border:1px solid #ddd;padding:8px">IEA-GHG-2013</td><td style="border:1px solid #ddd;padding:8px">Table D-15</td><td style="border:1px solid #ddd;padding:8px">2013</td><td style="border:1px solid #ddd;padding:8px">Input|Steel Slab</td><td style="border:1px solid #dd
# None
