# %% [markdown]
# # Electrolysis

# %%
# Preparing notebook.

# Importing dependencies.
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
from posted import TEDF
from itables import show

# Setting up plotly for plotting.
pd.options.plotting.backend = "plotly"
pio.renderers.default = "notebook_connected"

# Loading the TEDF.
tedf = TEDF.load("Tech|Electrolysis")

# Determine periods to show.
periods = [int(p) for p in tedf.raw.period.str.split(",").explode().unique() if p != "*"]

# %% [markdown]
# ## Aggregated parameters

# %% [markdown]
# All data added to the POSTED database is aggregated automatically using the POSTED framework. The result yields the following parameters:

# %%
aggregated = tedf.aggregate(
    period=periods,
    reference_capacity="Input Capacity|Electricity",
    reference_activity="Output|Hydrogen",
    interpolate_period=False,
    expand_not_specified=False,
    append_references=True,
    agg=["source", "size"],
    units={"Input|Heat": "kWh"},
)

show(
    aggregated
    .query("~variable.str.startswith('Total')")
    .pivot(
        index=aggregated.columns[:-3],
        columns=["variable", "unit"],
        values="value",
    )
    .map(lambda x: float(f"{x:.3g}") if not np.isnan(x) else x)
    .fillna("")
)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_0adce7e6_a1fb_4b37_a41f_ab01576b5b15"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_0adce7e6_a1fb_4b37_a41f_ab01576b5b15:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr>\n      <th></th>\n      <th>variable</th>\n      <th>CAPEX</th>\n      <th>Input Capacity|Electricity</th>\n      <th>Input Capacity|Water</th>\n      <th>Input|Electricity</th>\n      <th>OPEX Fixed</th>\n      <th>Output|Hydrogen</th>\n      <th>Input|Heat</th>\n    </tr>\n    <tr>\n      <th></th>\n      <th>unit</th>\n      <th>EUR_2024</th>\n      <th>kW</th>\n      <th>kg/h</th>\n      <th>kWh</th>\n      <th>EUR_2024/year</th>\n      <th>kg_H2</th>\n      <th>kWh</th>\n    </tr>\n    <tr>\n      <th>subtech</th>\n      <th>period</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[\"AEL\", 2020, 1860.0, 1.0, \" 0.174\", 52.6, 63.9, 1.0, \"\"], [\"AEL\", 2030, 1130.0, 1.0, \" 0.188\", 49.0, 63.5, 1.0, \"\"], [\"AEL\", 2040, 991.0, 1.0, \"\", 46.7, 43.3, 1.0, \"\"], [\"AEL\", 2050, 703.0, 1.0, \"\", 44.7, 31.0, 1.0, \"\"], [\"PEM\", 2020, 3390.0, 1.0, \" 0.166\", 58.3, 184.0, 1.0, \"\"], [\"PEM\", 2030, 1900.0, 1.0, \" 0.19\", 49.8, 193.0, 1.0, \"\"], [\"PEM\", 2040, 2260.0, 1.0, \"\", 49.0, 124.0, 1.0, \"\"], [\"PEM\", 2050, 1860.0, 1.0, \"\", 47.2, 102.0, 1.0, \"\"], [\"SOEC\", 2020, 9870.0, 1.0, \"\", 43.4, 2080.0, 1.0, \" 9.71\"], [\"SOEC\", 2030, 3880.0, 1.0, \"\", 41.3, 814.0, 1.0, \" 10.0\"], [\"SOEC\", 2040, 4630.0, 1.0, \"\", 40.7, 555.0, 1.0, \" 9.29\"], [\"SOEC\", 2050, 2600.0, 1.0, \"\", 39.8, 312.0, 1.0, \" 9.1\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ## CAPEX

# %% [markdown]
# The figure below gives an overview of CAPEX values reported by different sources across times, subtechnology (Alkaline, PEM, Solid Oxide), and plant size.

# %%
selected = tedf.select(
    period=periods,
    reference_capacity="Input Capacity|Electricity",
    reference_activity="Output|Hydrogen",
    interpolate_period=False,
    expand_not_specified=False,
)

df_plot = (
    selected
    .query("variable=='CAPEX'")
    .sort_values(by="size", key=lambda col: col.str.extract(r"([0-9]+) .*")[0].astype(float))
    .sort_values(by="period")
)

display(
    df_plot
    .plot.line(
        x="period",
        y="value",
        color="source",
        facet_col="size",
        facet_row="subtech",
        markers=True,
    )
    .update_xaxes(
        title=None,
    )
    .update_yaxes(
        title=None,
    )
    .for_each_annotation(
        lambda a: a.update(text=": ".join(a.text.split("=")))
    )
    .add_annotation(
        text="{variable} per {reference_variable}  [ {unit} / {reference_unit} ]".format(**df_plot.iloc[0]),
        x=-0.05,
        y=+0.5,
        textangle=-90,
        showarrow=False,
        xref="paper",
        yref="paper",
    )
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="a7f8ffd3-5bb6-4d77-940b-b8d49d996487" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a7f8ffd3-5bb6-4d77-940b-b8d49d996487")) {                    Plotly.newPlot(                        "a7f8ffd3-5bb6-4d77-940b-b8d49d996487",                        [{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=AEL\u003cbr\u003esize=1 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x9","y":{"dtype":"f8","bdata":"xwc9m3WkrkCGHrhRa1SmQNLuQRM\u002f0Z9AFyZTBaOKlkA="},"yaxis":"y9","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=AEL\u003cbr\u003esize=100 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x11","y":{"dtype":"f8","bdata":"PHYq84mSqkDIC1CUOKGhQEvNgVBFOZVAZlxf1icbkEA="},"yaxis":"y11","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=PEM\u003cbr\u003esize=1 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x5","y":{"dtype":"f8","bdata":"z7fvSrLouECVLKVV11+rQMgLUJQ4oaFA4uRyuLAXnUA="},"yaxis":"y5","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=PEM\u003cbr\u003esize=100 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x7","y":{"dtype":"f8","bdata":"z7fvSrLouECVLKVV11+rQMgLUJQ4oaFA4uRyuLAXnUA="},"yaxis":"y7","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=SOEC\u003cbr\u003esize=1 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x","y":{"dtype":"f8","bdata":"aTn7QQjl0ECIaVHeTYO6QHne9zxzFLJAzX96UNJQpEA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=AEL\u003cbr\u003esize=5 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Holst-2021","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuBw=="},"xaxis":"x10","y":{"dtype":"f8","bdata":"P3PWp5zTkUDa44V0eEaLQA=="},"yaxis":"y10","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=AEL\u003cbr\u003esize=100 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#EF553B","dash":"solid"}, ...

# %% [markdown]
# ## Electricity demand

# %%
aggregated = tedf.aggregate(
    period=periods,
    reference_capacity="Input Capacity|Electricity",
    reference_activity="Output|Hydrogen",
    interpolate_period=False,
    expand_not_specified=False,
    agg="size",
)

df_plot = (
    aggregated
    .query("variable=='Input|Electricity'")
    .sort_values(by="period")
)

display(
    df_plot
    .plot.line(
        x="period",
        y="value",
        color="source",
        facet_col="subtech",
        markers=True,
    )
    .update_xaxes(
        title=None,
    )
    .for_each_annotation(
        lambda a: a.update(text=": ".join(a.text.split("=")))
    )
    .update_layout(
        yaxis_title="{variable} per {reference_variable}  [ {unit} / {reference_unit} ]".format(**df_plot.iloc[0]),
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="39ff3243-1590-4d9c-bf09-2be175856e1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("39ff3243-1590-4d9c-bf09-2be175856e1f")) {                    Plotly.newPlot(                        "39ff3243-1590-4d9c-bf09-2be175856e1f",                        [{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=AEL\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAASUCDgoKCgoJIQNAX9AV9QUdAjuM4juM4RkA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=PEM\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x2","y":{"dtype":"f8","bdata":"J8ULZFK8TECngPlAdmFJQIOCgoKCgkhA6JCaYLyVR0A="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=SOEC\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x3","y":{"dtype":"f8","bdata":"f6xr7o91RUAeAjeWQalEQFMINIVAU0RA\u002fzIKAprrQ0A="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=AEL\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Holst-2021","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"zMzMzMyMSkAzMzMzM5NIQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=PEM\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Holst-2021","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuBw=="},"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZmZmS0DNzMzMzOxHQA=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"source=Tenhumberg-2020\u003cbr\u003esubtech=AEL\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tenhumberg-2020","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Tenhumberg-2020","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"9cUUikpCUEA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=Tenhumberg-2020\u003cbr\u003esubtech=PEM\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tenhumberg-2020","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Tenhumberg-2020","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5Ac="},"xaxis":"x2","y":{"dtype":"f8","bdata":"qRkyemgnUUA="},"yaxis":"y2","type":"scatter"},{"hoverte ...

# %% [markdown]
# ## Raw data

# %% [markdown]
# The table below contains the raw data contained in the public POSTED database. This data has not be automatically normalised or harmonised in any way. You can also find this data in the GitHub repo in this file:
# [posted/database/tedfs/Tech/Electrolysis.csv](https://github.com/PhilippVerpoort/posted/blob/main/posted/database/tedfs/Tech/Electrolysis.csv)

# %%
show(tedf.raw.fillna(""))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_9a431158_6a6b_4a0a_a61a_449ae721c00f"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.6.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_9a431158_6a6b_4a0a_a61a_449ae721c00f:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>source</th>\n      <th>subtech</th>\n      <th>size</th>\n      <th>period</th>\n      <th>variable</th>\n      <th>reference_variable</th>\n      <th>value</th>\n      <th>uncertainty</th>\n      <th>unit</th>\n      <th>reference_value</th>\n      <th>reference_unit</th>\n      <th>comment</th>\n      <th>source_detail</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"DEA-TDRF-2023\", \"AEL\", \"1 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", 1566.0, \" 918.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"AEL\", \"1 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", 1164.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"AEL\", \"1 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", 874.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"AEL\", \"1 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", 648.0, \" 438.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"AEL\", \"100 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", 1358.0, \" 374.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"AEL\", \"100 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", 919.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"AEL\", \"100 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", 583.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"AEL\", \"100 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", 463.0, \" 201.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 AEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"1 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", 2215.0, \" 497.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"1 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", 1378.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"1 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", 919.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"1 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", 788.0, \" 190.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 1MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"100 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", 2215.0, \" 497.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"100 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", 1378.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"100 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", 919.0, \"\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"PEM\", \"100 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", 788.0, \" 190.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 PEMEC 100MW, Row 24\"], [\"DEA-TDRF-2023\", \"SOEC\", \"1 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", 8047.0, \" 2163.0\", \"EUR_2020\", \" 1.0\", \"kg_H2/day\", \"\", \"Sheet 86 SOEC 1MW, Row 23\"], [\"DEA-TDRF-2023\", \"SOEC\", \"1 MW\", \"2030\", \"CAPEX\", \"Output  ...
