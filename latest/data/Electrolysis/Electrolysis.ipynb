# %% [markdown]
# # Electrolysis

# %%
# Dependencies.
from IPython.display import HTML, Markdown

import pandas as pd
pd.options.plotting.backend = "plotly"

from posted import TEDF


# Set variable of TEDF.
var = "Tech|Electrolysis"

# Loading the TEDF.
tedf = TEDF.load(var)

# Determine periods to show.
periods = [int(p) for p in tedf.raw.period.str.split(",").explode().unique() if p != "*"]

# %% [markdown]
# ## Fields

# %% [markdown]
# The techno-economic data is distinguished across the following additional fields.

# %% [markdown]
# ### Subtechnologies

# %%
Markdown(
    "\n".join(f"* **{code}**: {desc}" for code, desc in tedf.fields["subtech"].codes.items())
)
# Out:
# * **AEL**: Alkaline electrolysis
# * **PEM**: Proton-exchange membrane electrolysis
# * **SOEC**: High-temperature solid-oxide electrolysis

# %% [markdown]
# ### Size

# %% [markdown]
# Mainly CAPEX but also other parameters crucially depend on the size of an electrolysis plant. The size can be added as a non-coded field. For some sources, this may not be reported and hence set to `N/S` (not specified).

# %% [markdown]
# ## Aggregated parameters

# %% [markdown]
# All data added to the POSTED database is aggregated automatically using the POSTED framework. The result yields the following parameters:

# %%
aggregated = tedf.aggregate(
    period=periods,
    period_mode="none",
    reference_capacity="Input Capacity|Electricity",
    reference_activity="Output|Hydrogen",
    expand_not_specified=False,
    append_references=True,
    agg=["source", "size"],
    units={"Input|Heat": "kWh"},
)

display(
    aggregated
    .query("~variable.str.startswith('Total')")
    .pivot(
        index=aggregated.columns[:-3],
        columns=["variable", "unit"],
        values="value",
    )
    .map(lambda x: float(f"{x:.3g}") if not pd.isnull(x) else x)
    .fillna("")
)
# Out:
# variable          CAPEX Input Capacity|Electricity Input|Electricity  \
# unit           EUR_2024                         kW               kWh
# subtech period
# AEL     2020      919.0                        1.0              53.5
#         2030      576.0                        1.0              49.1
#         2040      357.0                        1.0              46.2
#         2050      265.0                        1.0              44.8
# PEM     2020     1280.0                        1.0              58.6
#         2030      807.0                        1.0              49.3
#         2040      541.0                        1.0              49.0
#         2050      482.0                        1.0              47.2
# SOEC    2020     3930.0                        1.0              44.1
#         2030     1630.0                        1.0              41.3
#         2040     1610.0                        1.0              40.7
#         2050      944.0                        1.0              39.8
#
# variable       Input|Water    OPEX Fixed Output|Hydrogen Input|Heat
# unit                kg_H2O EUR_2024/year           kg_H2        kWh
# subtech period
# AEL     2020          9.23         23.20             1.0
#         2030          9.22         15.90             1.0
#         2040                       11.70             1.0
#         2050                        9.12             1.0
# PEM     2020          9.07         39.60             1.0
#         2030          9.07         43.10             1.0
#         2040                       29.80             1.0
#         2050                       26.50             1.0
# SOEC    2020                      649.00             1.0       9.71
#         2030                      275.00             1.0       10.0
#         2040                      194.00             1.0       9.29
#         2050                      113.00             1.0        9.1

# %% [markdown]
# ## CAPEX

# %% [markdown]
# The figure below gives an overview of CAPEX values reported by different sources across times, subtechnology (Alkaline, PEM, Solid Oxide), and plant size.

# %%
selected = tedf.select(
    period=periods,
    period_mode="none",
    reference_capacity="Input Capacity|Electricity",
    reference_activity="Output|Hydrogen",
    expand_not_specified=False,
)

aggregated = tedf.aggregate(
    period=periods,
    period_mode="none",
    reference_capacity="Input Capacity|Electricity",
    reference_activity="Output|Hydrogen",
    expand_not_specified=False,
    agg=["source", "size"],
    units={"Input|Heat": "kWh"},
)

df_plot = (
    pd.concat([
        selected,
        aggregated.assign(source="POSTED-default", size="N/S"),
    ])
    .query("variable=='CAPEX'")
    .sort_values(by="size", key=lambda col: col.str.extract(r"([0-9]+) .*")[0].astype(float))
    .sort_values(by="period")
)

display(
    df_plot
    .plot.line(
        x="period",
        y="value",
        color="source",
        facet_col="size",
        facet_row="subtech",
        markers=True,
    )
    .update_xaxes(
        title=None,
    )
    .update_yaxes(
        title=None,
    )
    .for_each_annotation(
        lambda a: a.update(text=": ".join(a.text.split("=")))
    )
    .update_layout(
        legend_title=None,
        yaxis5_title="{variable} per {reference_variable}  ( {unit} / {reference_unit} )".format(**df_plot.iloc[0]),
    )
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b01e3061-24b5-4faa-bff8-b8844da9950c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b01e3061-24b5-4faa-bff8-b8844da9950c")) {                    Plotly.newPlot(                        "b01e3061-24b5-4faa-bff8-b8844da9950c",                        [{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=AEL\u003cbr\u003esize=1 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x9","y":{"dtype":"f8","bdata":"SBQgK3Q9jEDC3DHeFmmFQNg+fwJx8YBA86hb6t5KekA="},"yaxis":"y9","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=AEL\u003cbr\u003esize=100 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x11","y":{"dtype":"f8","bdata":"bZEXRjh9iECWPElybOeAQG99alKQmnZAnqBmqz\u002fJckA="},"yaxis":"y11","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=PEM\u003cbr\u003esize=1 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x5","y":{"dtype":"f8","bdata":"ltNPTB9gkUDinjlzIHqIQJY8SXJs54BA7+pG8CcgfkA="},"yaxis":"y5","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=PEM\u003cbr\u003esize=100 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x7","y":{"dtype":"f8","bdata":"ltNPTB9gkUDinjlzIHqIQJY8SXJs54BA7+pG8CcgfkA="},"yaxis":"y7","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=SOEC\u003cbr\u003esize=1 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x","y":{"dtype":"f8","bdata":"jg95o9QhtUAojAirGuOhQHS4Gj1lNZlAsI0NYDd9jUA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=AEL\u003cbr\u003esize=5 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Holst-2021","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuBw=="},"xaxis":"x10","y":{"dtype":"f8","bdata":"P3PWp5zTkUDa44V0eEaLQA=="},"yaxis":"y10","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=AEL\u003cbr\u003esize=100 MW\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#FF7F0E","dash":"solid"}, ...

# %% [markdown]
# ## Electricity demand

# %%
aggregated = tedf.aggregate(
    period=periods,
    period_mode="none",
    reference_capacity="Input Capacity|Electricity",
    reference_activity="Output|Hydrogen",
    expand_not_specified=False,
    agg="size",
)

df_plot = (
    aggregated
    .query("variable=='Input|Electricity'")
    .sort_values(by="period")
)

display(
    df_plot
    .plot.line(
        x="period",
        y="value",
        color="source",
        facet_col="subtech",
        markers=True,
    )
    .update_xaxes(
        title=None,
    )
    .for_each_annotation(
        lambda a: a.update(text=": ".join(a.text.split("=")))
    )
    .update_layout(
        yaxis_title="{variable} per {reference_variable}  [ {unit} / {reference_unit} ]".format(**df_plot.iloc[0]),
    )
    .update_layout(
        legend_title=None,
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="172491ed-15ff-413c-a62f-07aa77be9c21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("172491ed-15ff-413c-a62f-07aa77be9c21")) {                    Plotly.newPlot(                        "172491ed-15ff-413c-a62f-07aa77be9c21",                        [{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=AEL\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAASUCDgoKCgoJIQNAX9AV9QUdAjuM4juM4RkA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=PEM\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x2","y":{"dtype":"f8","bdata":"J8ULZFK8TECngPlAdmFJQIOCgoKCgkhA6JCaYLyVR0A="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"source=DEA-TDRF-2023\u003cbr\u003esubtech=SOEC\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DEA-TDRF-2023","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DEA-TDRF-2023","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x3","y":{"dtype":"f8","bdata":"f6xr7o91RUAeAjeWQalEQFMINIVAU0RA\u002fzIKAprrQ0A="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=AEL\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Holst-2021","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"zMzMzMyMSkAzMzMzM5NIQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=Holst-2021\u003cbr\u003esubtech=PEM\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Holst-2021","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Holst-2021","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"5AfuBw=="},"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZmZmS0DNzMzMzOxHQA=="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"source=Vartiainen-2022\u003cbr\u003esubtech=AEL\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vartiainen-2022","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vartiainen-2022","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5AfuB\u002fgHAgg="},"xaxis":"x","y":{"dtype":"f8","bdata":"7I+XwSjgSED1PM\u002fzPM9HQEztL7W\u002f1EZA4T6C+wjuRUA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"source=Tenhumberg-2020\u003cbr\u003esubtech=AEL\u003cbr\u003eperiod=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tenhumberg-2020","line":{"color":"#D62728","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Tenhumberg-2020","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"5Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"9c ...

# %% [markdown]
# ## Raw data

# %%
Markdown(f"""
The table below contains the raw data contained in the public POSTED database. This data has not be automatically normalised or harmonised in any way. You can also find this data in the GitHub repo in this file:
{link_public_github(var)}
""")
# Out:
# The table below contains the raw data contained in the public POSTED database. This data has not be automatically normalised or harmonised in any way. You can also find this data in the GitHub repo in this file:
# <a href="https://github.com/PhilippVerpoort/posted/blob/main/posted/database/tedfs/Tech/Electrolysis.csv">posted/database/tedfs/Tech/Electrolysis.csv</a>

# %%
tedf.edit_data()
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f59e55f7_2394_4926_a516_7ff4542e469d"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.7.0 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f59e55f7_2394_4926_a516_7ff4542e469d:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap", "compact"], "order": [], "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>source</th>\n      <th>source_detail</th>\n      <th>subtech</th>\n      <th>size</th>\n      <th>period</th>\n      <th>variable</th>\n      <th>reference_variable</th>\n      <th>value</th>\n      <th>uncertainty</th>\n      <th>unit</th>\n      <th>reference_value</th>\n      <th>reference_unit</th>\n      <th>comment</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"DEA-TDRF-2023\", \"Sheet 86 AEC 1MW, Row 24\", \"AEL\", \"1 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"1566\", \"918\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 AEC 1MW, Row 24\", \"AEL\", \"1 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"1164\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 AEC 1MW, Row 24\", \"AEL\", \"1 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"874\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 AEC 1MW, Row 24\", \"AEL\", \"1 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"648\", \"438\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 AEC 100MW, Row 24\", \"AEL\", \"100 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"1358\", \"374\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 AEC 100MW, Row 24\", \"AEL\", \"100 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"919\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 AEC 100MW, Row 24\", \"AEL\", \"100 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"583\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 AEC 100MW, Row 24\", \"AEL\", \"100 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"463\", \"201\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 1MW, Row 24\", \"PEM\", \"1 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"2215\", \"497\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 1MW, Row 24\", \"PEM\", \"1 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"1378\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 1MW, Row 24\", \"PEM\", \"1 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"919\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 1MW, Row 24\", \"PEM\", \"1 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"788\", \"190\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 100MW, Row 24\", \"PEM\", \"100 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"2215\", \"497\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 100MW, Row 24\", \"PEM\", \"100 MW\", \"2030\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"1378\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 100MW, Row 24\", \"PEM\", \"100 MW\", \"2040\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"919\", \"\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 PEMEC 100MW, Row 24\", \"PEM\", \"100 MW\", \"2050\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"788\", \"190\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 SOEC 1MW, Row 23\", \"SOEC\", \"1 MW\", \"2020\", \"CAPEX\", \"Output Capacity|Hydrogen\", \"8047\", \"2163\", \"EUR_2020\", \"1\", \"kg_H2/day\", \"\"], [\"DEA-TDRF-2023\", \"Sheet 86 SOEC 1MW, Row 23\", \"SOEC\", \"1 MW\", \"2030\", \"CAPEX\", \"Output Ca ...
