# %%
import pandas as pd
pd.options.plotting.backend = "plotly"
print("hi")

# %%
from posted.noslag import DataSet
# import posted.config
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
print("test")
tedf = TEDF('Tech|ELH2')
# tedf.load()
print("bakfewafes")
# tedf.check()
# print(tedf._var_specs)
# display(tedf.data)

# %%
DataSet('Tech|ELH2').normalise(override={'Tech|ELH2|Input Capacity|elec': 'kW', 'Tech|ELH2|Output Capacity|h2': 'kW;LHV'}).query("source=='Vartiainen22'")

# %%
DataSet('Tech|ELH2').data

# %%
DataSet('Tech|ELH2').select(period=2020, subtech='AEL', size='100 MW', override={'Tech|ELH2|Output Capacity|h2': 'kW;LHV'})
# Out:
# initialize TEBase
# {'Tech|ELH2|CAPEX': {'description': 'CAPital EXpenditure (in reference to capacity specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|CAPEX Annualised': {'description': 'Annualised CAPital EXpenditure (in reference to input or output specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Capital Cost': {'description': 'Capital cost of the technology per primary output capacity (not annualised) for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|CAPEX', 'reference_variable': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Fixed': {'description': 'OPerational EXpenditure fixed (in reference to capacity specified by reference variable) for technology ELH2', 'dimension': '[currency]/[time]', 'default_unit': 'USD_2005/a', 'default_reference': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Fixed Specific': {'description': 'OPerational EXpenditure fixed (in reference to input or output specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Fixed Relative': {'description': 'Annual Fixed OPerational EXpenditure as relative share of CAPEX for technology ELH2', 'dimension': 'dimensionless', 'default_unit': 'pct', 'primary_output': 'h2'}, 'Tech|ELH2|OM Cost Fixed': {'description': 'Fixed operation and maintenance cost of the technology per primary output capacity for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|OPEX Fixed', 'reference_variable': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Variable': {'description': 'Variable OPerational EXpenditure (non-energy, non-feedstock) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OM Cost Variable': {'description': 'Variable operation and maintenance cost of the technology (non-energy, non-feedstock) per primary output for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|OPEX Variable', 'reference_variable': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Lifetime': {'description': 'Expected time a facility can be in production for for technology ELH2', 'dimension': '[time]', 'default_unit': 'a', 'primary_output': 'h2'}, 'Tech|ELH2|OCF': {'description': 'Operational capacity factor for technology ELH2', 'dimension': 'dimensionless', 'default_unit': 'pct', 'primary_output': 'h2'}, 'Tech|ELH2|FLH': {'description': 'Full-load hours for technology ELH2', 'dimension': '[time]', 'default_unit': 'h', 'primary_output': 'h2'}, 'Tech|ELH2|Total Production Expenditure': {'description': 'Total expenditure for production (in reference to input or output specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Total Cost': {'description': 'Total cost of production per primary output for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|Total Production Expenditure', 'reference_variable': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Output|All Products Mass': {'description': 'Mass of all outputs produced for technology ELH2', 'dimension': '[mass]', 'default_unit': 't', 'primary_output': 'h2'}, 'Tech|ELH2|Output Capacity|All Products Mass': {'description': 'Capacity per mass of all outputs produced for technology ELH2', 'dimension': '[mass]/[time]', 'default_unit': 't', 'primary_output': 'h2'}, 'Tech|ELH2|Capture Rate': {'description': 'Share of CO2 emissions captured for technology ELH2', 'dimension': 'dimensionless', 'd ...
# databases
# None
# ['public']
# collected files =  [('Tech|ELH2', 'public')]
# initialize TEBase
# {'Tech|ELH2|CAPEX': {'description': 'CAPital EXpenditure (in reference to capacity specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|CAPEX Annualised': {'description': 'Annualised CAPital EXpenditure (in reference to input or output specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Capital Cost': {'description': 'Capital cost of the technology per primary output capacity (not annualised) for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|CAPEX', 'reference_variable': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Fixed': {'description': 'OPerational EXpenditure fixed (in reference to capacity specified by reference variable) for technology ELH2', 'dimension': '[currency]/[time]', 'default_unit': 'USD_2005/a', 'default_reference': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Fixed Specific': {'description': 'OPerational EXpenditure fixed (in reference to input or output specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Fixed Relative': {'description': 'Annual Fixed OPerational EXpenditure as relative share of CAPEX for technology ELH2', 'dimension': 'dimensionless', 'default_unit': 'pct', 'primary_output': 'h2'}, 'Tech|ELH2|OM Cost Fixed': {'description': 'Fixed operation and maintenance cost of the technology per primary output capacity for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|OPEX Fixed', 'reference_variable': 'Tech|ELH2|Output Capacity|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OPEX Variable': {'description': 'Variable OPerational EXpenditure (non-energy, non-feedstock) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|OM Cost Variable': {'description': 'Variable operation and maintenance cost of the technology (non-energy, non-feedstock) per primary output for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|OPEX Variable', 'reference_variable': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Lifetime': {'description': 'Expected time a facility can be in production for for technology ELH2', 'dimension': '[time]', 'default_unit': 'a', 'primary_output': 'h2'}, 'Tech|ELH2|OCF': {'description': 'Operational capacity factor for technology ELH2', 'dimension': 'dimensionless', 'default_unit': 'pct', 'primary_output': 'h2'}, 'Tech|ELH2|FLH': {'description': 'Full-load hours for technology ELH2', 'dimension': '[time]', 'default_unit': 'h', 'primary_output': 'h2'}, 'Tech|ELH2|Total Production Expenditure': {'description': 'Total expenditure for production (in reference to input or output specified by reference variable) for technology ELH2', 'dimension': '[currency]', 'default_unit': 'USD_2005', 'default_reference': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Total Cost': {'description': 'Total cost of production per primary output for technology ELH2', 'mapped': True, 'variable': 'Tech|ELH2|Total Production Expenditure', 'reference_variable': 'Tech|ELH2|Output|h2', 'primary_output': 'h2'}, 'Tech|ELH2|Output|All Products Mass': {'description': 'Mass of all outputs produced for technology ELH2', 'dimension': '[mass]', 'default_unit': 't', 'primary_output': 'h2'}, 'Tech|ELH2|Output Capacity|All Products Mass': {'description': 'Capacity per mass of all outputs produced for technology ELH2', 'dimension': '[mass]/[time]', 'default_unit': 't', 'primary_output': 'h2'}, 'Tech|ELH2|Capture Rate': {'description': 'Share of CO2 emissions captured for technology ELH2', 'dimension': 'dimensionless', 'd ...
# new fields =  {'subtech': <posted.columns.CustomFieldDefinition object at 0x7fde399bfe20>, 'size': <posted.columns.CustomFieldDefinition object at 0x7fde39b29120>}
# new comments =  {}
# col_id =  subtech
# col_id =  size
# col_id =  region
# dtype =  category
# default = *
# normalise
# selected after drop
#    subtech          size region period                             variable  \
# 1      AEL        100 MW      *   2020                      Tech|ELH2|CAPEX
# 2      AEL        100 MW      *   2030                      Tech|ELH2|CAPEX
# 3      AEL        100 MW      *   2040                      Tech|ELH2|CAPEX
# 4      AEL        100 MW      *   2050                      Tech|ELH2|CAPEX
# 5      AEL        100 MW      *   2020                      Tech|ELH2|CAPEX
# ..     ...           ...    ...    ...                                  ...
# 91     AEL             *      *   2020                Tech|ELH2|Input|water
# 92       *          1 MW      *      *  Tech|ELH2|Total Input Capacity|elec
# 93       *          5 MW      *      *  Tech|ELH2|Total Input Capacity|elec
# 94       *        100 MW      *      *  Tech|ELH2|Total Input Capacity|elec
# 95       *  130000 Nm³/h      *      *   Tech|ELH2|Total Output Capacity|h2
#
#                reference_variable         value        source
# 1   Tech|ELH2|Input Capacity|elec  4.540386e+01  Vartiainen22
# 2   Tech|ELH2|Input Capacity|elec  2.724232e+01  Vartiainen22
# 3   Tech|ELH2|Input Capacity|elec  1.589135e+01  Vartiainen22
# 4   Tech|ELH2|Input Capacity|elec  9.080772e+00  Vartiainen22
# 5   Tech|ELH2|Input Capacity|elec  7.525690e+01       Holst21
# ..                            ...           ...           ...
# 91            Tech|ELH2|Output|h2  2.994960e-01       Yates20
# 92                            NaN  8.760000e+03             *
# 93                            NaN  4.380000e+04             *
# 94                            NaN  8.760000e+05             *
# 95                            NaN  3.178875e+06             *
#
# [95 rows x 8 columns]
# field_id =  period
# field_id =  subtech
# field_id =  size
# field select items =  dict_items([('period', <posted.columns.PeriodFieldDefinition object at 0x7fde48d808e0>), ('subtech', <posted.columns.CustomFieldDefinition object at 0x7fde399bfe20>), ('size', <posted.columns.CustomFieldDefinition object at 0x7fde39b29120>), ('region', <posted.columns.RegionFieldDefinition object at 0x7fde493dd360>), ('source', <posted.columns.SourceFieldDefinition object at 0x7fde3a35cd90>)])
# col_id_select =  period
# access expand
# access select
# df after select
#     period subtech          size region                             variable  \
# 0     2020       *             *      *                Tech|ELH2|Input|water
# 1     2020       *          1 MW      *  Tech|ELH2|Total Input Capacity|elec
# 2     2020       *        100 MW      *  Tech|ELH2|Total Input Capacity|elec
# 3     2020       *  130000 Nm³/h      *   Tech|ELH2|Total Output Capacity|h2
# 4     2020       *          5 MW      *  Tech|ELH2|Total Input Capacity|elec
# 5     2020     AEL             *      *                      Tech|ELH2|CAPEX
# 6     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 7     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 8     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 9     2020     AEL             *      *                Tech|ELH2|Input|water
# 10    2020     AEL             *      *                 Tech|ELH2|OPEX Fixed
# 11    2020     AEL             *      *                 Tech|ELH2|OPEX Fixed
# 12    2020     AEL             *      *                  Tech|ELH2|Output|h2
# 13    2020     AEL          1 MW      *                      Tech|ELH2|CAPEX
# 14    2020     AEL          1 MW      *        Tech|ELH2|OPEX Fixed Relative
# 15    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 16    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 17    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 18    2020     AEL        100 MW      *                 Tech|ELH2|OPEX Fixed
# 19    2020     AEL        100 MW      *        Tech|ELH2|OPEX Fixed Relative
# 20    2020     AEL        100 MW      *                  Tech|ELH2|Output|h2
# 21    2020     AEL  130000 Nm³/h      *                      Tech|ELH2|CAPEX
# 22    2020     AEL  130000 Nm³/h      *                 Tech|ELH2|Input|elec
# 23    2020     AEL          5 MW      *                      Tech|ELH2|CAPEX
# 24    2020     PEM             *      *                 Tech|ELH2|Input|elec
# 25    2020     PEM             *      *                 Tech|ELH2|Input|elec
# 26    2020     PEM             *      *                Tech|ELH2|Input|water
# 27    2020     PEM             *      *                 Tech|ELH2|OPEX Fixed
# 28    2020     PEM             *      *                  Tech|ELH2|Output|h2
# 29    2020     PEM          1 MW      *                      Tech|ELH2|CAPEX
# 30    2020     PEM          1 MW      *        Tech|ELH2|OPEX Fixed Relative
# 31    2020     PEM        100 MW      *                      Tech|ELH2|CAPEX
# 32    2020     PEM        100 MW      *                      Tech|ELH2|CAPEX
# 33    2020     PEM        100 MW      *        Tech|ELH2|OPEX Fixed Relative
# 34    2020     PEM  130000 Nm³/h      *                      Tech|ELH2|CAPEX
# 35    2020     PEM  130000 Nm³/h      *                 Tech|ELH2|Input|elec
# 36    2020     PEM          5 MW      *                      Tech|ELH2|CAPEX
# 37    2020    SOEC             *      *                 Tech|ELH2|Input|heat
# 38    2020    SOEC             *      *                  Tech|ELH2|Output|h2
# 39    2020    SOEC          1 MW      *                      Tech|ELH2|CAPEX
# 40    2020    SOEC          1 MW      *        Tech|ELH2|OPEX Fixed Relative
# 41    2020    SOEC  130000 Nm³/h      *                      Tech|ELH2|CAPEX
# 42    2020    SOEC  130000 Nm³/h      *                 Tech|ELH2|Input|elec
# 43    2020    SOEC  130000 Nm³/h      *                 Tech|ELH2|Input|heat
#
#                reference_variable        source         value
# 0             Tech|ELH2|Output|h2     IEA-GHR21  2.700298e-01
# 1                             NaN             *  8.760000e+03
# 2                             NaN             *  8.760000e+05
# 3                             NaN             *  3.178875e+06
# 4                             NaN             *  4.380000e+04
# 5   Tech|ELH2|Input Capacity|elec       IRENA22  4.503196e+01
# 6             Tech|ELH2|Output|h2       Holst21  1.449160e+00
# 7             Tech|ELH2|Output|h2       IRENA22  1.510667e+00
# 8             Tech|ELH2|Output|h2       Yates20  1.620179e+00
# 9             Tech|ELH2|Output|h2       Yates20  2.994960e-01
# 10  Tech|ELH2|Input Capacity|elec       Holst21  2.270193e+00
# 11  Tech|ELH2|Input Capacity|elec       Yates20  1.492421e+00
# 12           Tech|ELH2|Input|elec       DEARF23  6.665931e-01
# 13   Tech|ELH2|Output Capacity|h2       DEARF23  1.121267e+03
# 14                            NaN       DEARF23  5.000000e+00
# 15  Tech|ELH2|Input Capacity|elec       Holst21  7.525690e+01
# 16  Tech|ELH2|Input Capacity|elec  Vartiainen22  4.540386e+01
# 17   Tech|ELH2|Output Capacity|h2       DEARF23  9.723376e+02
# 18  Tech|ELH2|Input Capacity|elec  Vartiainen22  6.810579e-01
# 19                            NaN       DEARF23  2.000000e+00
# 20           Tech|ELH2|Input|elec  Vartiainen22  6.700000e-01
# 21  Tech|ELH2|Input Capacity|elec  Tenhumberg20  1.328999e+02
# 22            Tech|ELH2|Output|h2  Tenhumberg20  1.952408e+00
# 23  Tech|ELH2|Input Capacity|elec       Holst21  1.077207e+02
# 24            Tech|ELH2|Output|h2  Al-Qahtani21  1.626179e+00
# 25            Tech|ELH2|Output|h2       Holst21  1.530169e+00
# 26            Tech|ELH2|Output|h2  Al-Qahtani21  3.000331e-01
# 27  Tech|ELH2|Input Capacity|elec       Holst21  1.702645e+00
# 28           Tech|ELH2|Input|elec       DEARF23  5.799360e-01
# 29   Tech|ELH2|Output Capacity|h2       DEARF23  1.585956e+03
# 30                            NaN       DEARF23  7.000000e+00
# 31  Tech|ELH2|Input Capacity|elec       Holst21  8.149993e+01
# 32   Tech|ELH2|Output Capacity|h2       DEARF23  1.585956e+03
# 33                            NaN       DEARF23  4.000000e+00
# 34  Tech|ELH2|Input Capacity|elec  Tenhumberg20  2.022389e+02
# 35            Tech|ELH2|Output|h2  Tenhumberg20  2.059880e+00
# 36  Tech|ELH2|Input Capacity|elec       Holst21  1.110124e+02
# 37           Tech|ELH2|Input|elec       DEARF23  2.578616e-01
# 38           Tech|ELH2|Input|elec       DEARF23  7.765810e-01
# 39   Tech|ELH2|Output Capacity|h2       DEARF23  5.761709e+03
# 40                            NaN       DEARF23  1.200000e+01
# 41  Tech|ELH2|Input Capacity|elec  Tenhumberg20  2.311302e+02
# 42            Tech|ELH2|Output|h2  Tenhumberg20  1.361312e+00
# 43            Tech|ELH2|Output|h2  Tenhumberg20  2.507679e-01
# col_id_select =  subtech
# cell =  AEL
# access expand
# col_id_expand =  subtech
#     period subtech          size region                             variable  \
# 5     2020     AEL             *      *                      Tech|ELH2|CAPEX
# 6     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 7     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 8     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 9     2020     AEL             *      *                Tech|ELH2|Input|water
# 10    2020     AEL             *      *                 Tech|ELH2|OPEX Fixed
# 11    2020     AEL             *      *                 Tech|ELH2|OPEX Fixed
# 12    2020     AEL             *      *                  Tech|ELH2|Output|h2
# 13    2020     AEL          1 MW      *                      Tech|ELH2|CAPEX
# 14    2020     AEL          1 MW      *        Tech|ELH2|OPEX Fixed Relative
# 15    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 16    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 17    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 18    2020     AEL        100 MW      *                 Tech|ELH2|OPEX Fixed
# 19    2020     AEL        100 MW      *        Tech|ELH2|OPEX Fixed Relative
# 20    2020     AEL        100 MW      *                  Tech|ELH2|Output|h2
# 21    2020     AEL  130000 Nm³/h      *                      Tech|ELH2|CAPEX
# 22    2020     AEL  130000 Nm³/h      *                 Tech|ELH2|Input|elec
# 23    2020     AEL          5 MW      *                      Tech|ELH2|CAPEX
# 0     2020     AEL             *      *                Tech|ELH2|Input|water
# 1     2020     AEL          1 MW      *  Tech|ELH2|Total Input Capacity|elec
# 2     2020     AEL        100 MW      *  Tech|ELH2|Total Input Capacity|elec
# 3     2020     AEL  130000 Nm³/h      *   Tech|ELH2|Total Output Capacity|h2
# 4     2020     AEL          5 MW      *  Tech|ELH2|Total Input Capacity|elec
#
#                reference_variable        source         value
# 5   Tech|ELH2|Input Capacity|elec       IRENA22  4.503196e+01
# 6             Tech|ELH2|Output|h2       Holst21  1.449160e+00
# 7             Tech|ELH2|Output|h2       IRENA22  1.510667e+00
# 8             Tech|ELH2|Output|h2       Yates20  1.620179e+00
# 9             Tech|ELH2|Output|h2       Yates20  2.994960e-01
# 10  Tech|ELH2|Input Capacity|elec       Holst21  2.270193e+00
# 11  Tech|ELH2|Input Capacity|elec       Yates20  1.492421e+00
# 12           Tech|ELH2|Input|elec       DEARF23  6.665931e-01
# 13   Tech|ELH2|Output Capacity|h2       DEARF23  1.121267e+03
# 14                            NaN       DEARF23  5.000000e+00
# 15  Tech|ELH2|Input Capacity|elec       Holst21  7.525690e+01
# 16  Tech|ELH2|Input Capacity|elec  Vartiainen22  4.540386e+01
# 17   Tech|ELH2|Output Capacity|h2       DEARF23  9.723376e+02
# 18  Tech|ELH2|Input Capacity|elec  Vartiainen22  6.810579e-01
# 19                            NaN       DEARF23  2.000000e+00
# 20           Tech|ELH2|Input|elec  Vartiainen22  6.700000e-01
# 21  Tech|ELH2|Input Capacity|elec  Tenhumberg20  1.328999e+02
# 22            Tech|ELH2|Output|h2  Tenhumberg20  1.952408e+00
# 23  Tech|ELH2|Input Capacity|elec       Holst21  1.077207e+02
# 0             Tech|ELH2|Output|h2     IEA-GHR21  2.700298e-01
# 1                             NaN             *  8.760000e+03
# 2                             NaN             *  8.760000e+05
# 3                             NaN             *  3.178875e+06
# 4                             NaN             *  4.380000e+04
# access select
# df after select
#     period subtech          size region                             variable  \
# 0     2020     AEL             *      *                      Tech|ELH2|CAPEX
# 1     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 2     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 3     2020     AEL             *      *                 Tech|ELH2|Input|elec
# 4     2020     AEL             *      *                Tech|ELH2|Input|water
# 5     2020     AEL             *      *                 Tech|ELH2|OPEX Fixed
# 6     2020     AEL             *      *                 Tech|ELH2|OPEX Fixed
# 7     2020     AEL             *      *                  Tech|ELH2|Output|h2
# 8     2020     AEL          1 MW      *                      Tech|ELH2|CAPEX
# 9     2020     AEL          1 MW      *        Tech|ELH2|OPEX Fixed Relative
# 10    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 11    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 12    2020     AEL        100 MW      *                      Tech|ELH2|CAPEX
# 13    2020     AEL        100 MW      *                 Tech|ELH2|OPEX Fixed
# 14    2020     AEL        100 MW      *        Tech|ELH2|OPEX Fixed Relative
# 15    2020     AEL        100 MW      *                  Tech|ELH2|Output|h2
# 16    2020     AEL  130000 Nm³/h      *                      Tech|ELH2|CAPEX
# 17    2020     AEL  130000 Nm³/h      *                 Tech|ELH2|Input|elec
# 18    2020     AEL          5 MW      *                      Tech|ELH2|CAPEX
# 19    2020     AEL             *      *                Tech|ELH2|Input|water
# 20    2020     AEL          1 MW      *  Tech|ELH2|Total Input Capacity|elec
# 21    2020     AEL        100 MW      *  Tech|ELH2|Total Input Capacity|elec
# 22    2020     AEL  130000 Nm³/h      *   Tech|ELH2|Total Output Capacity|h2
# 23    2020     AEL          5 MW      *  Tech|ELH2|Total Input Capacity|elec
#
#                reference_variable        source         value
# 0   Tech|ELH2|Input Capacity|elec       IRENA22  4.503196e+01
# 1             Tech|ELH2|Output|h2       Holst21  1.449160e+00
# 2             Tech|ELH2|Output|h2       IRENA22  1.510667e+00
# 3             Tech|ELH2|Output|h2       Yates20  1.620179e+00
# 4             Tech|ELH2|Output|h2       Yates20  2.994960e-01
# 5   Tech|ELH2|Input Capacity|elec       Holst21  2.270193e+00
# 6   Tech|ELH2|Input Capacity|elec       Yates20  1.492421e+00
# 7            Tech|ELH2|Input|elec       DEARF23  6.665931e-01
# 8    Tech|ELH2|Output Capacity|h2       DEARF23  1.121267e+03
# 9                             NaN       DEARF23  5.000000e+00
# 10  Tech|ELH2|Input Capacity|elec       Holst21  7.525690e+01
# 11  Tech|ELH2|Input Capacity|elec  Vartiainen22  4.540386e+01
# 12   Tech|ELH2|Output Capacity|h2       DEARF23  9.723376e+02
# 13  Tech|ELH2|Input Capacity|elec  Vartiainen22  6.810579e-01
# 14                            NaN       DEARF23  2.000000e+00
# 15           Tech|ELH2|Input|elec  Vartiainen22  6.700000e-01
# 16  Tech|ELH2|Input Capacity|elec  Tenhumberg20  1.328999e+02
# 17            Tech|ELH2|Output|h2  Tenhumberg20  1.952408e+00
# 18  Tech|ELH2|Input Capacity|elec       Holst21  1.077207e+02
# 19            Tech|ELH2|Output|h2     IEA-GHR21  2.700298e-01
# 20                            NaN             *  8.760000e+03
# 21                            NaN             *  8.760000e+05
# 22                            NaN             *  3.178875e+06
# 23                            NaN             *  4.380000e+04
# col_id_select =  size
# cell =  100 MW
# access expand
# col_id_expand =  size
#     period subtech    size region                             variable  \
# 10    2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 11    2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 12    2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 13    2020     AEL  100 MW      *                 Tech|ELH2|OPEX Fixed
# 14    2020     AEL  100 MW      *        Tech|ELH2|OPEX Fixed Relative
# 15    2020     AEL  100 MW      *                  Tech|ELH2|Output|h2
# 21    2020     AEL  100 MW      *  Tech|ELH2|Total Input Capacity|elec
# 0     2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 1     2020     AEL  100 MW      *                 Tech|ELH2|Input|elec
# 2     2020     AEL  100 MW      *                 Tech|ELH2|Input|elec
# 3     2020     AEL  100 MW      *                 Tech|ELH2|Input|elec
# 4     2020     AEL  100 MW      *                Tech|ELH2|Input|water
# 5     2020     AEL  100 MW      *                 Tech|ELH2|OPEX Fixed
# 6     2020     AEL  100 MW      *                 Tech|ELH2|OPEX Fixed
# 7     2020     AEL  100 MW      *                  Tech|ELH2|Output|h2
# 8     2020     AEL  100 MW      *                Tech|ELH2|Input|water
#
#                reference_variable        source          value
# 10  Tech|ELH2|Input Capacity|elec       Holst21      75.256897
# 11  Tech|ELH2|Input Capacity|elec  Vartiainen22      45.403860
# 12   Tech|ELH2|Output Capacity|h2       DEARF23     972.337578
# 13  Tech|ELH2|Input Capacity|elec  Vartiainen22       0.681058
# 14                            NaN       DEARF23       2.000000
# 15           Tech|ELH2|Input|elec  Vartiainen22       0.670000
# 21                            NaN             *  876000.000000
# 0   Tech|ELH2|Input Capacity|elec       IRENA22      45.031962
# 1             Tech|ELH2|Output|h2       Holst21       1.449160
# 2             Tech|ELH2|Output|h2       IRENA22       1.510667
# 3             Tech|ELH2|Output|h2       Yates20       1.620179
# 4             Tech|ELH2|Output|h2       Yates20       0.299496
# 5   Tech|ELH2|Input Capacity|elec       Holst21       2.270193
# 6   Tech|ELH2|Input Capacity|elec       Yates20       1.492421
# 7            Tech|ELH2|Input|elec       DEARF23       0.666593
# 8             Tech|ELH2|Output|h2     IEA-GHR21       0.270030
# access select
# df after select
#     period subtech    size region                             variable  \
# 0     2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 1     2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 2     2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 3     2020     AEL  100 MW      *                 Tech|ELH2|OPEX Fixed
# 4     2020     AEL  100 MW      *        Tech|ELH2|OPEX Fixed Relative
# 5     2020     AEL  100 MW      *                  Tech|ELH2|Output|h2
# 6     2020     AEL  100 MW      *  Tech|ELH2|Total Input Capacity|elec
# 7     2020     AEL  100 MW      *                      Tech|ELH2|CAPEX
# 8     2020     AEL  100 MW      *                 Tech|ELH2|Input|elec
# 9     2020     AEL  100 MW      *                 Tech|ELH2|Input|elec
# 10    2020     AEL  100 MW      *                 Tech|ELH2|Input|elec
# 11    2020     AEL  100 MW      *                Tech|ELH2|Input|water
# 12    2020     AEL  100 MW      *                 Tech|ELH2|OPEX Fixed
# 13    2020     AEL  100 MW      *                 Tech|ELH2|OPEX Fixed
# 14    2020     AEL  100 MW      *                  Tech|ELH2|Output|h2
# 15    2020     AEL  100 MW      *                Tech|ELH2|Input|water
#
#                reference_variable        source          value
# 0   Tech|ELH2|Input Capacity|elec       Holst21      75.256897
# 1   Tech|ELH2|Input Capacity|elec  Vartiainen22      45.403860
# 2    Tech|ELH2|Output Capacity|h2       DEARF23     972.337578
# 3   Tech|ELH2|Input Capacity|elec  Vartiainen22       0.681058
# 4                             NaN       DEARF23       2.000000
# 5            Tech|ELH2|Input|elec  Vartiainen22       0.670000
# 6                             NaN             *  876000.000000
# 7   Tech|ELH2|Input Capacity|elec       IRENA22      45.031962
# 8             Tech|ELH2|Output|h2       Holst21       1.449160
# 9             Tech|ELH2|Output|h2       IRENA22       1.510667
# 10            Tech|ELH2|Output|h2       Yates20       1.620179
# 11            Tech|ELH2|Output|h2       Yates20       0.299496
# 12  Tech|ELH2|Input Capacity|elec       Holst21       2.270193
# 13  Tech|ELH2|Input Capacity|elec       Yates20       1.492421
# 14           Tech|ELH2|Input|elec       DEARF23       0.666593
# 15            Tech|ELH2|Output|h2     IEA-GHR21       0.270030
# col_id_select =  region
# access expand
# col_id_expand =  region
#     period subtech    size region                             variable  \
# 0     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 1     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 2     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 3     2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 4     2020     AEL  100 MW  World        Tech|ELH2|OPEX Fixed Relative
# 5     2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 6     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 7     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 8     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 9     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 10    2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 11    2020     AEL  100 MW  World                Tech|ELH2|Input|water
# 12    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 13    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 14    2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 15    2020     AEL  100 MW  World                Tech|ELH2|Input|water
#
#                reference_variable        source          value
# 0   Tech|ELH2|Input Capacity|elec       Holst21      75.256897
# 1   Tech|ELH2|Input Capacity|elec  Vartiainen22      45.403860
# 2    Tech|ELH2|Output Capacity|h2       DEARF23     972.337578
# 3   Tech|ELH2|Input Capacity|elec  Vartiainen22       0.681058
# 4                             NaN       DEARF23       2.000000
# 5            Tech|ELH2|Input|elec  Vartiainen22       0.670000
# 6                             NaN             *  876000.000000
# 7   Tech|ELH2|Input Capacity|elec       IRENA22      45.031962
# 8             Tech|ELH2|Output|h2       Holst21       1.449160
# 9             Tech|ELH2|Output|h2       IRENA22       1.510667
# 10            Tech|ELH2|Output|h2       Yates20       1.620179
# 11            Tech|ELH2|Output|h2       Yates20       0.299496
# 12  Tech|ELH2|Input Capacity|elec       Holst21       2.270193
# 13  Tech|ELH2|Input Capacity|elec       Yates20       1.492421
# 14           Tech|ELH2|Input|elec       DEARF23       0.666593
# 15            Tech|ELH2|Output|h2     IEA-GHR21       0.270030
# access select
# df after select
#     period subtech    size region                             variable  \
# 0     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 1     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 2     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 3     2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 4     2020     AEL  100 MW  World        Tech|ELH2|OPEX Fixed Relative
# 5     2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 6     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 7     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 8     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 9     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 10    2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 11    2020     AEL  100 MW  World                Tech|ELH2|Input|water
# 12    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 13    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 14    2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 15    2020     AEL  100 MW  World                Tech|ELH2|Input|water
#
#                reference_variable        source          value
# 0   Tech|ELH2|Input Capacity|elec       Holst21      75.256897
# 1   Tech|ELH2|Input Capacity|elec  Vartiainen22      45.403860
# 2    Tech|ELH2|Output Capacity|h2       DEARF23     972.337578
# 3   Tech|ELH2|Input Capacity|elec  Vartiainen22       0.681058
# 4                             NaN       DEARF23       2.000000
# 5            Tech|ELH2|Input|elec  Vartiainen22       0.670000
# 6                             NaN             *  876000.000000
# 7   Tech|ELH2|Input Capacity|elec       IRENA22      45.031962
# 8             Tech|ELH2|Output|h2       Holst21       1.449160
# 9             Tech|ELH2|Output|h2       IRENA22       1.510667
# 10            Tech|ELH2|Output|h2       Yates20       1.620179
# 11            Tech|ELH2|Output|h2       Yates20       0.299496
# 12  Tech|ELH2|Input Capacity|elec       Holst21       2.270193
# 13  Tech|ELH2|Input Capacity|elec       Yates20       1.492421
# 14           Tech|ELH2|Input|elec       DEARF23       0.666593
# 15            Tech|ELH2|Output|h2     IEA-GHR21       0.270030
# col_id_select =  source
# access expand
# col_id_expand =  source
#     period subtech    size region                             variable  \
# 0     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 1     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 2     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 3     2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 4     2020     AEL  100 MW  World        Tech|ELH2|OPEX Fixed Relative
# 5     2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 7     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 8     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 9     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 10    2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 11    2020     AEL  100 MW  World                Tech|ELH2|Input|water
# 12    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 13    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 14    2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 15    2020     AEL  100 MW  World                Tech|ELH2|Input|water
# 0     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 1     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 2     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 3     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 4     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 5     2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
#
#                reference_variable        source          value
# 0   Tech|ELH2|Input Capacity|elec       Holst21      75.256897
# 1   Tech|ELH2|Input Capacity|elec  Vartiainen22      45.403860
# 2    Tech|ELH2|Output Capacity|h2       DEARF23     972.337578
# 3   Tech|ELH2|Input Capacity|elec  Vartiainen22       0.681058
# 4                             NaN       DEARF23       2.000000
# 5            Tech|ELH2|Input|elec  Vartiainen22       0.670000
# 7   Tech|ELH2|Input Capacity|elec       IRENA22      45.031962
# 8             Tech|ELH2|Output|h2       Holst21       1.449160
# 9             Tech|ELH2|Output|h2       IRENA22       1.510667
# 10            Tech|ELH2|Output|h2       Yates20       1.620179
# 11            Tech|ELH2|Output|h2       Yates20       0.299496
# 12  Tech|ELH2|Input Capacity|elec       Holst21       2.270193
# 13  Tech|ELH2|Input Capacity|elec       Yates20       1.492421
# 14           Tech|ELH2|Input|elec       DEARF23       0.666593
# 15            Tech|ELH2|Output|h2     IEA-GHR21       0.270030
# 0                             NaN       Holst21  876000.000000
# 1                             NaN  Vartiainen22  876000.000000
# 2                             NaN       DEARF23  876000.000000
# 3                             NaN       IRENA22  876000.000000
# 4                             NaN       Yates20  876000.000000
# 5                             NaN     IEA-GHR21  876000.000000
# access select
# df after select
#     period subtech    size region                             variable  \
# 0     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 1     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 2     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 3     2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 4     2020     AEL  100 MW  World        Tech|ELH2|OPEX Fixed Relative
# 5     2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 6     2020     AEL  100 MW  World                      Tech|ELH2|CAPEX
# 7     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 8     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 9     2020     AEL  100 MW  World                 Tech|ELH2|Input|elec
# 10    2020     AEL  100 MW  World                Tech|ELH2|Input|water
# 11    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 12    2020     AEL  100 MW  World                 Tech|ELH2|OPEX Fixed
# 13    2020     AEL  100 MW  World                  Tech|ELH2|Output|h2
# 14    2020     AEL  100 MW  World                Tech|ELH2|Input|water
# 15    2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 16    2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 17    2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 18    2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 19    2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
# 20    2020     AEL  100 MW  World  Tech|ELH2|Total Input Capacity|elec
#
#                reference_variable        source          value
# 0   Tech|ELH2|Input Capacity|elec       Holst21      75.256897
# 1   Tech|ELH2|Input Capacity|elec  Vartiainen22      45.403860
# 2    Tech|ELH2|Output Capacity|h2       DEARF23     972.337578
# 3   Tech|ELH2|Input Capacity|elec  Vartiainen22       0.681058
# 4                             NaN       DEARF23       2.000000
# 5            Tech|ELH2|Input|elec  Vartiainen22       0.670000
# 6   Tech|ELH2|Input Capacity|elec       IRENA22      45.031962
# 7             Tech|ELH2|Output|h2       Holst21       1.449160
# 8             Tech|ELH2|Output|h2       IRENA22       1.510667
# 9             Tech|ELH2|Output|h2       Yates20       1.620179
# 10            Tech|ELH2|Output|h2       Yates20       0.299496
# 11  Tech|ELH2|Input Capacity|elec       Holst21       2.270193
# 12  Tech|ELH2|Input Capacity|elec       Yates20       1.492421
# 13           Tech|ELH2|Input|elec       DEARF23       0.666593
# 14            Tech|ELH2|Output|h2     IEA-GHR21       0.270030
# 15                            NaN       Holst21  876000.000000
# 16                            NaN  Vartiainen22  876000.000000
# 17                            NaN       DEARF23  876000.000000
# 18                            NaN       IRENA22  876000.000000
# 19                            NaN       Yates20  876000.000000
# 20                            NaN     IEA-GHR21  876000.000000
# type selected =  <class 'pandas.core.frame.DataFrame'>
# apply mappings
# keys =  (2020, 'World', 'DEARF23')
# ids =  Index([2, 4, 13, 17], dtype='int64')
# rows =  <class 'pandas.core.frame.DataFrame'>
#                                variable            reference_variable  \
# 2                       Tech|ELH2|CAPEX  Tech|ELH2|Output Capacity|h2
# 4         Tech|ELH2|OPEX Fixed Relative                           NaN
# 13                  Tech|ELH2|Output|h2          Tech|ELH2|Input|elec
# 17  Tech|ELH2|Total Input Capacity|elec                           NaN
#
#             value
# 2      972.337578
# 4        2.000000
# 13       0.666593
# 17  876000.000000
# cond 1 =  2     False
# 4     False
# 13    False
# 17    False
# Name: variable, dtype: bool
#                                variable            reference_variable  \
# 2                       Tech|ELH2|CAPEX  Tech|ELH2|Output Capacity|h2
# 4         Tech|ELH2|OPEX Fixed Relative                           NaN
# 13                  Tech|ELH2|Output|h2          Tech|ELH2|Input|elec
# 17  Tech|ELH2|Total Input Capacity|elec                           NaN
#
#             value
# 2      972.337578
# 4        2.000000
# 13       0.666593
# 17  876000.000000
# cond 2 =  2     False
# 4      True
# 13    False
# 17    False
# Name: variable, dtype: bool
# 4    2.0
# Name: value, dtype: float64
#                         variable reference_variable  value
# 4  Tech|ELH2|OPEX Fixed Relative                NaN    2.0
# pct
# 0.01
# 1.0
#           variable            reference_variable       value
# 2  Tech|ELH2|CAPEX  Tech|ELH2|Output Capacity|h2  972.337578
#                                variable            reference_variable  \
# 2                       Tech|ELH2|CAPEX  Tech|ELH2|Output Capacity|h2
# 4                  Tech|ELH2|OPEX Fixed  Tech|ELH2|Output Capacity|h2
# 13                  Tech|ELH2|Output|h2          Tech|ELH2|Input|elec
# 17  Tech|ELH2|Total Input Capacity|elec                           NaN
#
#             value
# 2      972.337578
# 4       19.446752
# 13       0.666593
# 17  876000.000000
# cond 3 =  2     False
# 4     False
# 13    False
# 17    False
# Name: variable, dtype: bool
# 4rows =  2     False
# 4     False
# 13     True
# 17    False
# Name: variable, dtype: bool
# 2     Tech|ELH2|Output Capacity|h2
# 4     Tech|ELH2|Output Capacity|h2
# 13            Tech|ELH2|Input|elec
# 17                             NaN
# Name: reference_variable, dtype: object
# cond 4 =  2     False
# 4     False
# 13     True
# 17    False
# dtype: bool
# 2     Tech|ELH2|Output Capacity|h2
# 4     Tech|ELH2|Output Capacity|h2
# 13             Tech|ELH2|Output|h2
# 17                             NaN
# Name: reference_variable, dtype: object
# cond51 =  2      True
# 4      True
# 13     True
# 17    False
# Name: reference_variable, dtype: bool
# cond52 = 2      True
# 4      True
# 13     True
# 17    False
# Name: variable, dtype: bool
# cond53 =  2     False
# 4     False
# 13    False
# 17     True
# dtype: bool
# cond 5 =  2     False
# 4     False
# 13    False
# 17    False
# dtype: bool
# keys =  (2020, 'World', 'Holst21')
# ids =  Index([0, 7, 11, 15], dtype='int64')
# rows =  <class 'pandas.core.frame.DataFrame'>
#                                variable             reference_variable  \
# 0                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 7                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 11                 Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 15  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 0       75.256897
# 7        1.449160
# 11       2.270193
# 15  876000.000000
# cond 1 =  0     False
# 7     False
# 11    False
# 15    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 0                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 7                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 11                 Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 15  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 0       75.256897
# 7        1.449160
# 11       2.270193
# 15  876000.000000
# cond 2 =  0     False
# 7     False
# 11    False
# 15    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 0                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 7                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 11                 Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 15  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 0       75.256897
# 7        1.449160
# 11       2.270193
# 15  876000.000000
# cond 3 =  0     False
# 7     False
# 11    False
# 15    False
# Name: variable, dtype: bool
# 4rows =  0     False
# 7     False
# 11    False
# 15    False
# Name: variable, dtype: bool
# 0     Tech|ELH2|Input Capacity|elec
# 7               Tech|ELH2|Output|h2
# 11    Tech|ELH2|Input Capacity|elec
# 15                              NaN
# Name: reference_variable, dtype: object
# cond 4 =  0     False
# 7     False
# 11    False
# 15    False
# dtype: bool
# cond51 =  0      True
# 7      True
# 11     True
# 15    False
# Name: reference_variable, dtype: bool
# cond52 = 0      True
# 7      True
# 11     True
# 15    False
# Name: variable, dtype: bool
# cond53 =  0      True
# 7     False
# 11     True
# 15     True
# dtype: bool
# cond 5 =  0      True
# 7     False
# 11     True
# 15    False
# dtype: bool
# keys =  (2020, 'World', 'IEA-GHR21')
# ids =  Index([14, 20], dtype='int64')
# rows =  <class 'pandas.core.frame.DataFrame'>
#                                variable   reference_variable         value
# 14                Tech|ELH2|Input|water  Tech|ELH2|Output|h2       0.27003
# 20  Tech|ELH2|Total Input Capacity|elec                  NaN  876000.00000
# cond 1 =  14    False
# 20    False
# Name: variable, dtype: bool
#                                variable   reference_variable         value
# 14                Tech|ELH2|Input|water  Tech|ELH2|Output|h2       0.27003
# 20  Tech|ELH2|Total Input Capacity|elec                  NaN  876000.00000
# cond 2 =  14    False
# 20    False
# Name: variable, dtype: bool
#                                variable   reference_variable         value
# 14                Tech|ELH2|Input|water  Tech|ELH2|Output|h2       0.27003
# 20  Tech|ELH2|Total Input Capacity|elec                  NaN  876000.00000
# cond 3 =  14    False
# 20    False
# Name: variable, dtype: bool
# 4rows =  14    False
# 20    False
# Name: variable, dtype: bool
# 14    Tech|ELH2|Output|h2
# 20                    NaN
# Name: reference_variable, dtype: object
# cond 4 =  14    False
# 20    False
# dtype: bool
# cond51 =  14     True
# 20    False
# Name: reference_variable, dtype: bool
# cond52 = 14     True
# 20    False
# Name: variable, dtype: bool
# cond53 =  14    False
# 20     True
# dtype: bool
# cond 5 =  14    False
# 20    False
# dtype: bool
# keys =  (2020, 'World', 'IRENA22')
# ids =  Index([6, 8, 18], dtype='int64')
# rows =  <class 'pandas.core.frame.DataFrame'>
#                                variable             reference_variable  \
# 6                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 8                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 18  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 6       45.031962
# 8        1.510667
# 18  876000.000000
# cond 1 =  6     False
# 8     False
# 18    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 6                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 8                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 18  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 6       45.031962
# 8        1.510667
# 18  876000.000000
# cond 2 =  6     False
# 8     False
# 18    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 6                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 8                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 18  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 6       45.031962
# 8        1.510667
# 18  876000.000000
# cond 3 =  6     False
# 8     False
# 18    False
# Name: variable, dtype: bool
# 4rows =  6     False
# 8     False
# 18    False
# Name: variable, dtype: bool
# 6     Tech|ELH2|Input Capacity|elec
# 8               Tech|ELH2|Output|h2
# 18                              NaN
# Name: reference_variable, dtype: object
# cond 4 =  6     False
# 8     False
# 18    False
# dtype: bool
# cond51 =  6      True
# 8      True
# 18    False
# Name: reference_variable, dtype: bool
# cond52 = 6      True
# 8      True
# 18    False
# Name: variable, dtype: bool
# cond53 =  6      True
# 8     False
# 18     True
# dtype: bool
# cond 5 =  6      True
# 8     False
# 18    False
# dtype: bool
# keys =  (2020, 'World', 'Vartiainen22')
# ids =  Index([1, 3, 5, 16], dtype='int64')
# rows =  <class 'pandas.core.frame.DataFrame'>
#                                variable             reference_variable  \
# 1                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 3                  Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 5                   Tech|ELH2|Output|h2           Tech|ELH2|Input|elec
# 16  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 1       45.403860
# 3        0.681058
# 5        0.670000
# 16  876000.000000
# cond 1 =  1     False
# 3     False
# 5     False
# 16    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 1                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 3                  Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 5                   Tech|ELH2|Output|h2           Tech|ELH2|Input|elec
# 16  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 1       45.403860
# 3        0.681058
# 5        0.670000
# 16  876000.000000
# cond 2 =  1     False
# 3     False
# 5     False
# 16    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 1                       Tech|ELH2|CAPEX  Tech|ELH2|Input Capacity|elec
# 3                  Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 5                   Tech|ELH2|Output|h2           Tech|ELH2|Input|elec
# 16  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 1       45.403860
# 3        0.681058
# 5        0.670000
# 16  876000.000000
# cond 3 =  1     False
# 3     False
# 5     False
# 16    False
# Name: variable, dtype: bool
# 4rows =  1     False
# 3     False
# 5      True
# 16    False
# Name: variable, dtype: bool
# 1     Tech|ELH2|Input Capacity|elec
# 3     Tech|ELH2|Input Capacity|elec
# 5              Tech|ELH2|Input|elec
# 16                              NaN
# Name: reference_variable, dtype: object
# cond 4 =  1     False
# 3     False
# 5      True
# 16    False
# dtype: bool
# 1     Tech|ELH2|Input Capacity|elec
# 3     Tech|ELH2|Input Capacity|elec
# 5               Tech|ELH2|Output|h2
# 16                              NaN
# Name: reference_variable, dtype: object
# cond51 =  1      True
# 3      True
# 5      True
# 16    False
# Name: reference_variable, dtype: bool
# cond52 = 1      True
# 3      True
# 5      True
# 16    False
# Name: variable, dtype: bool
# cond53 =  1      True
# 3      True
# 5     False
# 16     True
# dtype: bool
# cond 5 =  1      True
# 3      True
# 5     False
# 16    False
# dtype: bool
# keys =  (2020, 'World', 'Yates20')
# ids =  Index([9, 10, 12, 19], dtype='int64')
# rows =  <class 'pandas.core.frame.DataFrame'>
#                                variable             reference_variable  \
# 9                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 10                Tech|ELH2|Input|water            Tech|ELH2|Output|h2
# 12                 Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 19  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 9        1.620179
# 10       0.299496
# 12       1.492421
# 19  876000.000000
# cond 1 =  9     False
# 10    False
# 12    False
# 19    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 9                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 10                Tech|ELH2|Input|water            Tech|ELH2|Output|h2
# 12                 Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 19  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 9        1.620179
# 10       0.299496
# 12       1.492421
# 19  876000.000000
# cond 2 =  9     False
# 10    False
# 12    False
# 19    False
# Name: variable, dtype: bool
#                                variable             reference_variable  \
# 9                  Tech|ELH2|Input|elec            Tech|ELH2|Output|h2
# 10                Tech|ELH2|Input|water            Tech|ELH2|Output|h2
# 12                 Tech|ELH2|OPEX Fixed  Tech|ELH2|Input Capacity|elec
# 19  Tech|ELH2|Total Input Capacity|elec                            NaN
#
#             value
# 9        1.620179
# 10       0.299496
# 12       1.492421
# 19  876000.000000
# cond 3 =  9     False
# 10    False
# 12    False
# 19    False
# Name: variable, dtype: bool
# 4rows =  9     False
# 10    False
# 12    False
# 19    False
# Name: variable, dtype: bool
# 9               Tech|ELH2|Output|h2
# 10              Tech|ELH2|Output|h2
# 12    Tech|ELH2|Input Capacity|elec
# 19                              NaN
# Name: reference_variable, dtype: object
# cond 4 =  9     False
# 10    False
# 12    False
# 19    False
# dtype: bool
# cond51 =  9      True
# 10     True
# 12     True
# 19    False
# Name: reference_variable, dtype: bool
# cond52 = 9      True
# 10     True
# 12     True
# 19    False
# Name: variable, dtype: bool
# cond53 =  9     False
# 10    False
# 12     True
# 19     True
# dtype: bool
# cond 5 =  9     False
# 10    False
# 12     True
# 19    False
# dtype: bool
# cols sorted =  ['source', 'variable', 'region', 'period', 'value']
# df aftter unit insert
#           source                             variable region  period  unit  \
# 0        DEARF23               Tech|ELH2|Capital Cost  World    2020   NaN
# 1        DEARF23                Tech|ELH2|Demand|elec  World    2020   NaN
# 2        DEARF23              Tech|ELH2|OM Cost Fixed  World    2020   NaN
# 3        DEARF23  Tech|ELH2|Total Input Capacity|elec  World    2020   NaN
# 4        Holst21               Tech|ELH2|Capital Cost  World    2020   NaN
# 5        Holst21                Tech|ELH2|Demand|elec  World    2020   NaN
# 6        Holst21              Tech|ELH2|OM Cost Fixed  World    2020   NaN
# 7        Holst21  Tech|ELH2|Total Input Capacity|elec  World    2020   NaN
# 8      IEA-GHR21               Tech|ELH2|Demand|water  World    2020   NaN
# 9      IEA-GHR21  Tech|ELH2|Total Input Capacity|elec  World    2020   NaN
# 10       IRENA22               Tech|ELH2|Capital Cost  World    2020   NaN
# 11       IRENA22                Tech|ELH2|Demand|elec  World    2020   NaN
# 12       IRENA22  Tech|ELH2|Total Input Capacity|elec  World    2020   NaN
# 13  Vartiainen22               Tech|ELH2|Capital Cost  World    2020   NaN
# 14  Vartiainen22                Tech|ELH2|Demand|elec  World    2020   NaN
# 15  Vartiainen22              Tech|ELH2|OM Cost Fixed  World    2020   NaN
# 16  Vartiainen22  Tech|ELH2|Total Input Capacity|elec  World    2020   NaN
# 17       Yates20                Tech|ELH2|Demand|elec  World    2020   NaN
# 18       Yates20               Tech|ELH2|Demand|water  World    2020   NaN
# 19       Yates20              Tech|ELH2|OM Cost Fixed  World    2020   NaN
# 20       Yates20  Tech|ELH2|Total Input Capacity|elec  World    2020   NaN
#
#           value
# 0      972.3000
# 1        1.5000
# 2       19.4500
# 3   876000.0000
# 4      955.4000
# 5        1.4490
# 6       28.8200
# 7   876000.0000
# 8        0.2700
# 9   876000.0000
# 10     595.9000
# 11       1.5110
# 12  876000.0000
# 13     593.6000
# 14       1.4930
# 15       8.9050
# 16  876000.0000
# 17       1.6200
# 18       0.2995
# 19      21.1800
# 20  876000.0000
# df with unit
#           source                             variable region  period  \
# 0        DEARF23               Tech|ELH2|Capital Cost  World    2020
# 1        DEARF23                Tech|ELH2|Demand|elec  World    2020
# 2        DEARF23              Tech|ELH2|OM Cost Fixed  World    2020
# 3        DEARF23  Tech|ELH2|Total Input Capacity|elec  World    2020
# 4        Holst21               Tech|ELH2|Capital Cost  World    2020
# 5        Holst21                Tech|ELH2|Demand|elec  World    2020
# 6        Holst21              Tech|ELH2|OM Cost Fixed  World    2020
# 7        Holst21  Tech|ELH2|Total Input Capacity|elec  World    2020
# 8      IEA-GHR21               Tech|ELH2|Demand|water  World    2020
# 9      IEA-GHR21  Tech|ELH2|Total Input Capacity|elec  World    2020
# 10       IRENA22               Tech|ELH2|Capital Cost  World    2020
# 11       IRENA22                Tech|ELH2|Demand|elec  World    2020
# 12       IRENA22  Tech|ELH2|Total Input Capacity|elec  World    2020
# 13  Vartiainen22               Tech|ELH2|Capital Cost  World    2020
# 14  Vartiainen22                Tech|ELH2|Demand|elec  World    2020
# 15  Vartiainen22              Tech|ELH2|OM Cost Fixed  World    2020
# 16  Vartiainen22  Tech|ELH2|Total Input Capacity|elec  World    2020
# 17       Yates20                Tech|ELH2|Demand|elec  World    2020
# 18       Yates20               Tech|ELH2|Demand|water  World    2020
# 19       Yates20              Tech|ELH2|OM Cost Fixed  World    2020
# 20       Yates20  Tech|ELH2|Total Input Capacity|elec  World    2020
#
#              unit        value
# 0     USD_2005/kW     972.3000
# 1         MWh/MWh       1.5000
# 2   USD_2005/a/kW      19.4500
# 3           MWh/a  876000.0000
# 4     USD_2005/kW     955.4000
# 5         MWh/MWh       1.4490
# 6   USD_2005/a/kW      28.8200
# 7           MWh/a  876000.0000
# 8           t/MWh       0.2700
# 9           MWh/a  876000.0000
# 10    USD_2005/kW     595.9000
# 11        MWh/MWh       1.5110
# 12          MWh/a  876000.0000
# 13    USD_2005/kW     593.6000
# 14        MWh/MWh       1.4930
# 15  USD_2005/a/kW       8.9050
# 16          MWh/a  876000.0000
# 17        MWh/MWh       1.6200
# 18          t/MWh       0.2995
# 19  USD_2005/a/kW      21.1800
# 20          MWh/a  876000.0000
#           source                             variable region  period  \
# 0        DEARF23               Tech|ELH2|Capital Cost  World    2020
# 1        DEARF23                Tech|ELH2|Demand|elec  World    2020
# 2        DEARF23              Tech|ELH2|OM Cost Fixed  World    2020
# 3        DEARF23  Tech|ELH2|Total Input Capacity|elec  World    2020
# 4        Holst21               Tech|ELH2|Capital Cost  World    2020
# 5        Holst21                Tech|ELH2|Demand|elec  World    2020
# 6        Holst21              Tech|ELH2|OM Cost Fixed  World    2020
# 7        Holst21  Tech|ELH2|Total Input Capacity|elec  World    2020
# 8      IEA-GHR21               Tech|ELH2|Demand|water  World    2020
# 9      IEA-GHR21  Tech|ELH2|Total Input Capacity|elec  World    2020
# 10       IRENA22               Tech|ELH2|Capital Cost  World    2020
# 11       IRENA22                Tech|ELH2|Demand|elec  World    2020
# 12       IRENA22  Tech|ELH2|Total Input Capacity|elec  World    2020
# 13  Vartiainen22               Tech|ELH2|Capital Cost  World    2020
# 14  Vartiainen22                Tech|ELH2|Demand|elec  World    2020
# 15  Vartiainen22              Tech|ELH2|OM Cost Fixed  World    2020
# 16  Vartiainen22  Tech|ELH2|Total Input Capacity|elec  World    2020
# 17       Yates20                Tech|ELH2|Demand|elec  World    2020
# 18       Yates20               Tech|ELH2|Demand|water  World    2020
# 19       Yates20              Tech|ELH2|OM Cost Fixed  World    2020
# 20       Yates20  Tech|ELH2|Total Input Capacity|elec  World    2020
#
#              unit        value
# 0     USD_2005/kW     972.3000
# 1         MWh/MWh       1.5000
# 2   USD_2005/a/kW      19.4500
# 3           MWh/a  876000.0000
# 4     USD_2005/kW     955.4000
# 5         MWh/MWh       1.4490
# 6   USD_2005/a/kW      28.8200
# 7           MWh/a  876000.0000
# 8           t/MWh       0.2700
# 9           MWh/a  876000.0000
# 10    USD_2005/kW     595.9000
# 11        MWh/MWh       1.5110
# 12          MWh/a  876000.0000
# 13    USD_2005/kW     593.6000
# 14        MWh/MWh       1.4930
# 15  USD_2005/a/kW       8.9050
# 16          MWh/a  876000.0000
# 17        MWh/MWh       1.6200
# 18          t/MWh       0.2995
# 19  USD_2005/a/kW      21.1800
# 20          MWh/a  876000.0000

# %%
DataSet('Tech|ELH2').select(period=2030, source='Yates20', subtech='AEL', size='100 MW', override={'Tech|ELH2|Output Capacity|h2': 'kW;LHV'}, extrapolate_period=False)

# %%
DataSet('Tech|ELH2').select(subtech=['AEL', 'PEM'], size='100 MW', override={'Tech|ELH2|Input Capacity|elec': 'kW'})

# %%
DataSet('Tech|ELH2').aggregate(subtech='AEL', size='100 MW', agg='subtech', override={'Tech|ELH2|Output Capacity|h2': 'kW;LHV'})

# %%
from posted.units import unit_convert
df_compare_electrolysis = DataSet('Tech|ELH2') \
    .select(period=[2020, 2030, 2040, 2050], subtech=['AEL', 'PEM'], override={'Tech|ELH2|Output Capacity|h2': 'kW;LHV'}, source=['DEARF23', 'Vartiainen22', 'Holst21', 'IRENA22'], size=['1 MW', '5 MW', '100 MW'], extrapolate_period=False) \
    .query(f"variable=='Tech|ELH2|Capital Cost'")
display(df_compare_electrolysis)
df_compare_electrolysis \
    .assign(size_sort=lambda df: df['size'].str.split(' ', n=1, expand=True).iloc[:, 0].astype(int)) \
    .sort_values(by=['size_sort', 'period']) \
    .plot.line(x='period', y='value', color='source', facet_col='size', facet_row='subtech')

# %%
display(DataSet('Tech|NG-REFORMING').aggregate(period=2030).query("variable.str.contains('OM Cost')"))
display(DataSet('Tech|NG-REFORMING').aggregate(period=2030).query("variable.str.contains('Demand')"))

display(DataSet('Tech|NG-REFORMING').aggregate(period=2030).sort_values(by='variable'))

# %%
TEDF('Tech|DAC').load().data

# %%
DataSet('Tech|DAC').normalise()

# %%
DataSet('Tech|DAC').select()

# %%
#NSHADataSet('Tech|MEOH-SYN').select(period=2040)

# %%
TEDF('Tech|HBNH3-ASU').load().check()
DataSet('Tech|HBNH3-ASU').normalise()

# %%
DataSet('Tech|HBNH3-ASU').select(period=2020)

# %%
DataSet('Tech|HBNH3-ASU').aggregate(period=2020)
