# %%
import pandas as pd
pd.options.plotting.backend = "plotly"
pd.set_option('display.max_rows', None)
print("hi")

# %%
import pandas as pd
pd.options.plotting.backend = "plotly"
pd.set_option('display.max_rows', None)
from posted.noslag import DataSet
from posted.tedf import TEDF
# import posted.config
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
print("test")
tedf = TEDF('Tech|ELH2')
# tedf.load()
print("bakfewafes")
# tedf.check()
# print(tedf._var_specs)
# display(tedf.data)

# %%
DataSet('Tech|Electrolysis').normalise(override={'Tech|ELH2|Input Capacity|Electricity': 'kW', 'Tech|ELH2|Output Capacity|h2': 'kW;LHV'}).query("source=='Vartiainen22'")

# %%
DataSet('Tech|Electrolysis').normalise(override={ 'Tech|ELH2|Output Capacity|Hydrogen': 'kW;LHV'})

# %%
DataSet('Tech|Electrolysis').select(period=2020, subtech='AEL', size='100 MW', override={'Tech|Electrolosys|Output Capacity|Hydrogen': 'kW;LHV'})

# %%
DataSet('Tech|Electrolysis').select(period=2030, source='Yates20', subtech='AEL', size='100 MW', override={'Tech|Electrolysis|Output Capacity|h2': 'kW;LHV'}, extrapolate_period=False)

# %%
DataSet('Tech|Electrolysis').select(subtech=['AEL', 'PEM'], size='100 MW', override={'Tech|Electrolysis|Input Capacity|Electricity': 'kW'})

# %%
DataSet('Tech|Electrolysis').aggregate(subtech='AEL', size='100 MW', agg='subtech', override={'Tech|ELH2|Output Capacity|Hydrogen': 'kW;LHV'})

# %%
from posted.units import unit_convert
df_compare_electrolysis = DataSet('Tech|ELH2') \
    .select(period=[2020, 2030, 2040, 2050], subtech=['AEL', 'PEM'], override={'Tech|ELH2|Output Capacity|h2': 'kW;LHV'}, source=['DEARF23', 'Vartiainen22', 'Holst21', 'IRENA22'], size=['1 MW', '5 MW', '100 MW'], extrapolate_period=False) \
    .query(f"variable=='Tech|ELH2|Capital Cost'")
display(df_compare_electrolysis)
df_compare_electrolysis \
    .assign(size_sort=lambda df: df['size'].str.split(' ', n=1, expand=True).iloc[:, 0].astype(int)) \
    .sort_values(by=['size_sort', 'period']) \
    .plot.line(x='period', y='value', color='source', facet_col='size', facet_row='subtech')

# %%
display(DataSet('Tech|NG-REFORMING').aggregate(period=2030).query("variable.str.contains('OM Cost')"))
display(DataSet('Tech|NG-REFORMING').aggregate(period=2030).query("variable.str.contains('Demand')"))

display(DataSet('Tech|NG-REFORMING').aggregate(period=2030).sort_values(by='variable'))

# %%
TEDF('Tech|Direct Air Capture').load().data

# %%
DataSet('Tech|Direct Air Capture').normalise()

# %%
DataSet('Tech|Direct Air Capture').select()
# Out:
# row loop in _select
#     period        value
# 7   2020.0  1013.933814
# 30  2050.0   276.188106
# 31  2050.0   115.700423
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source]
# Index: []
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, period_combined]
# Index: []
# rows_extrapolate
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, period_combined, value]
# Index: []
#    period  period_upper  period_lower subtech component region  \
# 0    2030        2050.0        2020.0  HT-DAC         #  World
# 1    2030        2050.0        2020.0  HT-DAC         #  World
# 2    2040        2050.0        2020.0  HT-DAC         #  World
# 3    2040        2050.0        2020.0  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
# 3  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable    source  value_upper  \
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Fasihi19   276.188106
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Fasihi19   115.700423
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Fasihi19   276.188106
# 3  Tech|Direct Air Capture|Output Capacity|Captur...  Fasihi19   115.700423
#
#    value_lower       value
# 0  1013.933814  522.103342
# 1  1013.933814  415.111553
# 2  1013.933814  768.018578
# 3  1013.933814  714.522684
#    period        value
# 0  2018.0  1149.795918
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source  period_combined
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18           2018.0
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18           2018.0
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18           2018.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source  \
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Keith18
#
#    period_combined        value
# 0           2018.0  1149.795918
# 1           2018.0  1149.795918
# 2           2018.0  1149.795918
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period   value
# 51     NaN  1255.0
# 52     NaN   675.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source  period_combined
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19              NaN
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19              NaN
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2030           NaN           NaN  HT-DAC         #  World
# 2    2040           NaN           NaN  HT-DAC         #  World
# 3    2040           NaN           NaN  HT-DAC         #  World
# 4    2050           NaN           NaN  HT-DAC         #  World
# 5    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
# 3  Tech|Direct Air Capture|CAPEX
# 4  Tech|Direct Air Capture|CAPEX
# 5  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source  \
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
# 3  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
# 4  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
# 5  Tech|Direct Air Capture|Output Capacity|Captur...  NASEM19
#
#    period_combined   value
# 0              NaN  1255.0
# 1              NaN   675.0
# 2              NaN  1255.0
# 3              NaN   675.0
# 4              NaN  1255.0
# 5              NaN   675.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period  value
# 20     NaN   80.0
# 21     NaN  150.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source  period_combined
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22              NaN
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22              NaN
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2030           NaN           NaN  HT-DAC         #  World
# 2    2040           NaN           NaN  HT-DAC         #  World
# 3    2040           NaN           NaN  HT-DAC         #  World
# 4    2050           NaN           NaN  HT-DAC         #  World
# 5    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
# 3  Tech|Direct Air Capture|CAPEX
# 4  Tech|Direct Air Capture|CAPEX
# 5  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable   source  \
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
# 3  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
# 4  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
# 5  Tech|Direct Air Capture|Output Capacity|Captur...  Okzan22
#
#    period_combined  value
# 0              NaN   80.0
# 1              NaN  150.0
# 2              NaN   80.0
# 3              NaN  150.0
# 4              NaN   80.0
# 5              NaN  150.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period        value
# 43     NaN  3607.862652
# 45     NaN  2736.999254
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable     source
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable     source  \
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
#
#    period_combined
# 0              NaN
# 1              NaN
# 2              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2030           NaN           NaN  HT-DAC         #  World
# 2    2040           NaN           NaN  HT-DAC         #  World
# 3    2040           NaN           NaN  HT-DAC         #  World
# 4    2050           NaN           NaN  HT-DAC         #  World
# 5    2050           NaN           NaN  HT-DAC         #  World
#
#                         variable  \
# 0  Tech|Direct Air Capture|CAPEX
# 1  Tech|Direct Air Capture|CAPEX
# 2  Tech|Direct Air Capture|CAPEX
# 3  Tech|Direct Air Capture|CAPEX
# 4  Tech|Direct Air Capture|CAPEX
# 5  Tech|Direct Air Capture|CAPEX
#
#                                   reference_variable     source  \
# 0  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 1  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 2  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 3  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 4  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
# 5  Tech|Direct Air Capture|Output Capacity|Captur...  Socolow11
#
#    period_combined        value
# 0              NaN  3607.862652
# 1              NaN  2736.999254
# 2              NaN  3607.862652
# 3              NaN  2736.999254
# 4              NaN  3607.862652
# 5              NaN  2736.999254
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period   value
# 63  2020.0  8000.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                       variable  reference_variable    source
# 0  Tech|Direct Air Capture|FLH                 NaN  Fasihi19
# 1  Tech|Direct Air Capture|FLH                 NaN  Fasihi19
# 2  Tech|Direct Air Capture|FLH                 NaN  Fasihi19
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                       variable  reference_variable    source  period_combined
# 0  Tech|Direct Air Capture|FLH                 NaN  Fasihi19           2020.0
# 1  Tech|Direct Air Capture|FLH                 NaN  Fasihi19           2020.0
# 2  Tech|Direct Air Capture|FLH                 NaN  Fasihi19           2020.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                       variable  reference_variable    source  period_combined  \
# 0  Tech|Direct Air Capture|FLH                 NaN  Fasihi19           2020.0
# 1  Tech|Direct Air Capture|FLH                 NaN  Fasihi19           2020.0
# 2  Tech|Direct Air Capture|FLH                 NaN  Fasihi19           2020.0
#
#     value
# 0  8000.0
# 1  8000.0
# 2  8000.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period   value
# 42     NaN  8000.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                       variable  reference_variable     source
# 0  Tech|Direct Air Capture|FLH                 NaN  Socolow11
# 1  Tech|Direct Air Capture|FLH                 NaN  Socolow11
# 2  Tech|Direct Air Capture|FLH                 NaN  Socolow11
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                       variable  reference_variable     source  period_combined
# 0  Tech|Direct Air Capture|FLH                 NaN  Socolow11              NaN
# 1  Tech|Direct Air Capture|FLH                 NaN  Socolow11              NaN
# 2  Tech|Direct Air Capture|FLH                 NaN  Socolow11              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                       variable  reference_variable     source  \
# 0  Tech|Direct Air Capture|FLH                 NaN  Socolow11
# 1  Tech|Direct Air Capture|FLH                 NaN  Socolow11
# 2  Tech|Direct Air Capture|FLH                 NaN  Socolow11
#
#    period_combined   value
# 0              NaN  8000.0
# 1              NaN  8000.0
# 2              NaN  8000.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#    period  value
# 2  2018.0  0.366
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                                     variable  \
# 0  Tech|Direct Air Capture|Input|Electricity
# 1  Tech|Direct Air Capture|Input|Electricity
# 2  Tech|Direct Air Capture|Input|Electricity
#
#                             reference_variable   source
# 0  Tech|Direct Air Capture|Output|Captured CO2  Keith18
# 1  Tech|Direct Air Capture|Output|Captured CO2  Keith18
# 2  Tech|Direct Air Capture|Output|Captured CO2  Keith18
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                                     variable  \
# 0  Tech|Direct Air Capture|Input|Electricity
# 1  Tech|Direct Air Capture|Input|Electricity
# 2  Tech|Direct Air Capture|Input|Electricity
#
#                             reference_variable   source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                                     variable  \
# 0  Tech|Direct Air Capture|Input|Electricity
# 1  Tech|Direct Air Capture|Input|Electricity
# 2  Tech|Direct Air Capture|Input|Electricity
#
#                             reference_variable   source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
#
#    value
# 0  0.366
# 1  0.366
# 2  0.366
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period  value
# 40     NaN   0.49
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                                     variable  \
# 0  Tech|Direct Air Capture|Input|Electricity
# 1  Tech|Direct Air Capture|Input|Electricity
# 2  Tech|Direct Air Capture|Input|Electricity
#
#                             reference_variable     source
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                                     variable  \
# 0  Tech|Direct Air Capture|Input|Electricity
# 1  Tech|Direct Air Capture|Input|Electricity
# 2  Tech|Direct Air Capture|Input|Electricity
#
#                             reference_variable     source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                                     variable  \
# 0  Tech|Direct Air Capture|Input|Electricity
# 1  Tech|Direct Air Capture|Input|Electricity
# 2  Tech|Direct Air Capture|Input|Electricity
#
#                             reference_variable     source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
#
#    value
# 0   0.49
# 1   0.49
# 2   0.49
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period     value
# 16  2022.0  1.472222
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2022.0  HT-DAC         #  World
# 1    2040           NaN        2022.0  HT-DAC         #  World
# 2    2050           NaN        2022.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable     source
# 0  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
# 1  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
# 2  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2022.0  HT-DAC         #  World
# 1    2040           NaN        2022.0  HT-DAC         #  World
# 2    2050           NaN        2022.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable     source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2022.0  HT-DAC         #  World
# 1    2040           NaN        2022.0  HT-DAC         #  World
# 2    2050           NaN        2022.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable     source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
#
#       value
# 0  1.472222
# 1  1.472222
# 2  1.472222
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#    period     value
# 3  2018.0  1.458333
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable   source
# 0  Tech|Direct Air Capture|Output|Captured CO2  Keith18
# 1  Tech|Direct Air Capture|Output|Captured CO2  Keith18
# 2  Tech|Direct Air Capture|Output|Captured CO2  Keith18
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable   source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable   source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  Keith18           2018.0
#
#       value
# 0  1.458333
# 1  1.458333
# 2  1.458333
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period     value
# 12  2021.0  1.833333
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2021.0  HT-DAC         #  World
# 1    2040           NaN        2021.0  HT-DAC         #  World
# 2    2050           NaN        2021.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable   source
# 0  Tech|Direct Air Capture|Output|Captured CO2  Madhu21
# 1  Tech|Direct Air Capture|Output|Captured CO2  Madhu21
# 2  Tech|Direct Air Capture|Output|Captured CO2  Madhu21
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2021.0  HT-DAC         #  World
# 1    2040           NaN        2021.0  HT-DAC         #  World
# 2    2050           NaN        2021.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable   source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  Madhu21           2021.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  Madhu21           2021.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  Madhu21           2021.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2021.0  HT-DAC         #  World
# 1    2040           NaN        2021.0  HT-DAC         #  World
# 2    2050           NaN        2021.0  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable   source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  Madhu21           2021.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  Madhu21           2021.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  Madhu21           2021.0
#
#       value
# 0  1.833333
# 1  1.833333
# 2  1.833333
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period  value
# 41     NaN   2.25
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable     source
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable     source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                              variable  \
# 0  Tech|Direct Air Capture|Input|Heat
# 1  Tech|Direct Air Capture|Input|Heat
# 2  Tech|Direct Air Capture|Input|Heat
#
#                             reference_variable     source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
#
#    value
# 0   2.25
# 1   2.25
# 2   2.25
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period  value
# 19  2022.0   25.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2022.0  HT-DAC         #  World
# 1    2040           NaN        2022.0  HT-DAC         #  World
# 2    2050           NaN        2022.0  HT-DAC         #  World
#
#                               variable  \
# 0  Tech|Direct Air Capture|Input|Water
# 1  Tech|Direct Air Capture|Input|Water
# 2  Tech|Direct Air Capture|Input|Water
#
#                             reference_variable     source
# 0  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
# 1  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
# 2  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2022.0  HT-DAC         #  World
# 1    2040           NaN        2022.0  HT-DAC         #  World
# 2    2050           NaN        2022.0  HT-DAC         #  World
#
#                               variable  \
# 0  Tech|Direct Air Capture|Input|Water
# 1  Tech|Direct Air Capture|Input|Water
# 2  Tech|Direct Air Capture|Input|Water
#
#                             reference_variable     source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2022.0  HT-DAC         #  World
# 1    2040           NaN        2022.0  HT-DAC         #  World
# 2    2050           NaN        2022.0  HT-DAC         #  World
#
#                               variable  \
# 0  Tech|Direct Air Capture|Input|Water
# 1  Tech|Direct Air Capture|Input|Water
# 2  Tech|Direct Air Capture|Input|Water
#
#                             reference_variable     source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 1  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
# 2  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22           2022.0
#
#    value
# 0   25.0
# 1   25.0
# 2   25.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#    period  value
# 9  2020.0   25.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                            variable  reference_variable    source
# 0  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
# 1  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
# 2  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                            variable  reference_variable    source  \
# 0  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
# 1  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
# 2  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
#
#    period_combined
# 0           2020.0
# 1           2020.0
# 2           2020.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                            variable  reference_variable    source  \
# 0  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
# 1  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
# 2  Tech|Direct Air Capture|Lifetime                 NaN  Fasihi19
#
#    period_combined  value
# 0           2020.0   25.0
# 1           2020.0   25.0
# 2           2020.0   25.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#    period  value
# 8  2020.0    3.7
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                                       variable  reference_variable    source
# 0  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
# 1  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
# 2  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                                       variable  reference_variable    source  \
# 0  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
# 1  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
# 2  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
#
#    period_combined
# 0           2020.0
# 1           2020.0
# 2           2020.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2020.0  HT-DAC         #  World
# 1    2040           NaN        2020.0  HT-DAC         #  World
# 2    2050           NaN        2020.0  HT-DAC         #  World
#
#                                       variable  reference_variable    source  \
# 0  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
# 1  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
# 2  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Fasihi19
#
#    period_combined  value
# 0           2020.0    3.7
# 1           2020.0    3.7
# 2           2020.0    3.7
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period  value
# 61  2018.0    4.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                                       variable  reference_variable   source
# 0  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
# 1  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
# 2  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                                       variable  reference_variable   source  \
# 0  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
# 1  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
# 2  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
#
#    period_combined
# 0           2018.0
# 1           2018.0
# 2           2018.0
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN        2018.0  HT-DAC         #  World
# 1    2040           NaN        2018.0  HT-DAC         #  World
# 2    2050           NaN        2018.0  HT-DAC         #  World
#
#                                       variable  reference_variable   source  \
# 0  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
# 1  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
# 2  Tech|Direct Air Capture|OPEX Fixed Relative                 NaN  Keith18
#
#    period_combined  value
# 0           2018.0    4.0
# 1           2018.0    4.0
# 2           2018.0    4.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period  value
# 24     NaN   40.0
# 25     NaN   80.0
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                                       variable  \
# 0  Tech|Direct Air Capture|OPEX Fixed Specific
# 1  Tech|Direct Air Capture|OPEX Fixed Specific
# 2  Tech|Direct Air Capture|OPEX Fixed Specific
#
#                             reference_variable   source
# 0  Tech|Direct Air Capture|Output|Captured CO2  Okzan22
# 1  Tech|Direct Air Capture|Output|Captured CO2  Okzan22
# 2  Tech|Direct Air Capture|Output|Captured CO2  Okzan22
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                                       variable  \
# 0  Tech|Direct Air Capture|OPEX Fixed Specific
# 1  Tech|Direct Air Capture|OPEX Fixed Specific
# 2  Tech|Direct Air Capture|OPEX Fixed Specific
#
#                             reference_variable   source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2030           NaN           NaN  HT-DAC         #  World
# 2    2040           NaN           NaN  HT-DAC         #  World
# 3    2040           NaN           NaN  HT-DAC         #  World
# 4    2050           NaN           NaN  HT-DAC         #  World
# 5    2050           NaN           NaN  HT-DAC         #  World
#
#                                       variable  \
# 0  Tech|Direct Air Capture|OPEX Fixed Specific
# 1  Tech|Direct Air Capture|OPEX Fixed Specific
# 2  Tech|Direct Air Capture|OPEX Fixed Specific
# 3  Tech|Direct Air Capture|OPEX Fixed Specific
# 4  Tech|Direct Air Capture|OPEX Fixed Specific
# 5  Tech|Direct Air Capture|OPEX Fixed Specific
#
#                             reference_variable   source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# 3  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# 4  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
# 5  Tech|Direct Air Capture|Output|Captured CO2  Okzan22              NaN
#
#    value
# 0   40.0
# 1   80.0
# 2   40.0
# 3   80.0
# 4   40.0
# 5   80.0
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period       value
# 44     NaN  149.290868
# 46     NaN  149.290868
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                                 variable  \
# 0  Tech|Direct Air Capture|OPEX Variable
# 1  Tech|Direct Air Capture|OPEX Variable
# 2  Tech|Direct Air Capture|OPEX Variable
#
#                             reference_variable     source
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2040           NaN           NaN  HT-DAC         #  World
# 2    2050           NaN           NaN  HT-DAC         #  World
#
#                                 variable  \
# 0  Tech|Direct Air Capture|OPEX Variable
# 1  Tech|Direct Air Capture|OPEX Variable
# 2  Tech|Direct Air Capture|OPEX Variable
#
#                             reference_variable     source  period_combined
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# rows_extrapolate
#    period  period_upper  period_lower subtech component region  \
# 0    2030           NaN           NaN  HT-DAC         #  World
# 1    2030           NaN           NaN  HT-DAC         #  World
# 2    2040           NaN           NaN  HT-DAC         #  World
# 3    2040           NaN           NaN  HT-DAC         #  World
# 4    2050           NaN           NaN  HT-DAC         #  World
# 5    2050           NaN           NaN  HT-DAC         #  World
#
#                                 variable  \
# 0  Tech|Direct Air Capture|OPEX Variable
# 1  Tech|Direct Air Capture|OPEX Variable
# 2  Tech|Direct Air Capture|OPEX Variable
# 3  Tech|Direct Air Capture|OPEX Variable
# 4  Tech|Direct Air Capture|OPEX Variable
# 5  Tech|Direct Air Capture|OPEX Variable
#
#                             reference_variable     source  period_combined  \
# 0  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 1  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 2  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 3  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 4  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
# 5  Tech|Direct Air Capture|Output|Captured CO2  Socolow11              NaN
#
#         value
# 0  149.290868
# 1  149.290868
# 2  149.290868
# 3  149.290868
# 4  149.290868
# 5  149.290868
# Empty DataFrame
# Columns: [period, period_upper, period_lower, subtech, component, region, variable, reference_variable, source, value_upper, value_lower, value]
# Index: []
#     period     value
# 67  2022.0  0.138889
#    period  period_upper  period_lower subtech        component region  \
# 0    2030           NaN        2022.0  HT-DAC  CO2 compression  World
# 1    2040           NaN        2022.0  HT-DAC  CO2 compression  World
# 2    2050           NaN        2022.0  HT-DAC  CO2 compression  World
#
#                                     variable  \
# 0  Tech|Direct Air Capture|Input|Electricity
# 1  Tech|Direct Air Capture|Input|Electricity
# 2  Tech|Direct Air Capture|Input|Electricity
#
#                             reference_variable     source
# 0  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
# 1  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
# 2  Tech|Direct Air Capture|Output|Captured CO2  IEA-DAC22
#    period  period_upper  period_lower subtech        component region  \
# 0    2030           NaN        2022.0  HT-DAC  CO2 compression  World
# 1    2040           NaN        2022.0  HT-DAC  CO2 compression  World
# 2    2050           NaN        2022.0  HT-DAC  CO2 compression  World
#
#                                     variable  \
# ...
# 42   Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 43   Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 44   Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 45   Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 46   Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 47   Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 48   Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 49   Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 50   Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 51   Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 52   Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 53   Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 54         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 55         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 56         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 57         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 58         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 59         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 60                                                 NaN  World    2030
# 61                                                 NaN  World    2040
# 62                                                 NaN  World    2050
# 63         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 64         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 65         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 66         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 67         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 68         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 69         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 70         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 71         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 72         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 73         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 74         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 75         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 76         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 77         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 78         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 79         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 80         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 81         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 82         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 83         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 84         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 85         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 86         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 87         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 88         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 89         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 90         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 91         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 92         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 93         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 94         Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 95         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 96         Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 97         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 98         Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 99   Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 100  Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 101  Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 102  Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 103  Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 104  Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 105        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 106        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 107        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 108        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 109        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 110        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 111                                                NaN  World    2030
# 112                                                NaN  World    2040
# 113                                                NaN  World    2050
# 114                                                NaN  World    2030
# 115                                                NaN  World    2040
# 116                                                NaN  World    2050
# 117  Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 118  Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 119  Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 120        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 121        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 122        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 123  Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 124  Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 125  Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 126        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 127        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 128        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 129        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 130        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 131        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 132                                                NaN  World    2030
# 133                                                NaN  World    2030
# 134                                                NaN  World    2040
# 135                                                NaN  World    2040
# 136                                                NaN  World    2050
# 137                                                NaN  World    2050
# 138                                                NaN  World    2030
# 139                                                NaN  World    2040
# 140                                                NaN  World    2050
# 141  Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 142  Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 143  Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 144        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 145        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 146        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 147  Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 148  Tech|Direct Air Capture|Output Capacity|Captur...  World    2030
# 149  Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 150  Tech|Direct Air Capture|Output Capacity|Captur...  World    2040
# 151  Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 152  Tech|Direct Air Capture|Output Capacity|Captur...  World    2050
# 153        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 154        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 155        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 156        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 157        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 158        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 159        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 160        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 161        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 162        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 163        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 164        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 165        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 166        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 167        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 168        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 169        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 170        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 171        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 172        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 173        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 174        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 175        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 176        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 177        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 178        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 179        Tech|Direct Air Capture|Output|Captured CO2  World    2050
# 180        Tech|Direct Air Capture|Output|Captured CO2  World    2030
# 181        Tech|Direct Air Capture|Output|Captured CO2  World    2040
# 182        Tech|Direct Air Capture|Output|Captured CO2  World    2050
#
#              unit      value
# 0    USD_2005·a/t   522.1000
# 1    USD_2005·a/t   415.1000
# 2    USD_2005·a/t   768.0000
# 3    USD_2005·a/t   714.5000
# 4    USD_2005·a/t   276.2000
# 5    USD_2005·a/t   115.7000
# 6               a    25.0000
# 7               a    25.0000
# 8               a    25.0000
# 9             pct     0.9132
# 10            pct     0.9132
# 11            pct     0.9132
# 12     USD_2005/t    19.3200
# 13     USD_2005/t    28.4200
# 14     USD_2005/t    10.2200
# 15          MWh/t     1.4720
# 16          MWh/t     1.4720
# 17          MWh/t     1.4720
# 18            t/t    25.0000
# 19            t/t    25.0000
# 20            t/t    25.0000
# 21   USD_2005·a/t  1150.0000
# 22   USD_2005·a/t  1150.0000
# 23   USD_2005·a/t  1150.0000
# 24          MWh/t     0.3660
# 25          MWh/t     0.3660
# 26          MWh/t     0.3660
# 27          MWh/t     1.4580
# 28          MWh/t     1.4580
# 29          MWh/t     1.4580
# 30     USD_2005/t    45.9900
# 31     USD_2005/t    45.9900
# 32     USD_2005/t    45.9900
# 33          MWh/t     1.8330
# 34          MWh/t     1.8330
# 35          MWh/t     1.8330
# 36   USD_2005·a/t  1255.0000
# 37   USD_2005·a/t   675.0000
# 38   USD_2005·a/t  1255.0000
# 39   USD_2005·a/t   675.0000
# 40   USD_2005·a/t  1255.0000
# 41   USD_2005·a/t   675.0000
# 42   USD_2005·a/t    80.0000
# 43   USD_2005·a/t   150.0000
# 44   USD_2005·a/t    80.0000
# 45   USD_2005·a/t   150.0000
# 46   USD_2005·a/t    80.0000
# 47   USD_2005·a/t   150.0000
# 48   USD_2005·a/t  3608.0000
# 49   USD_2005·a/t  2737.0000
# 50   USD_2005·a/t  3608.0000
# 51   USD_2005·a/t  2737.0000
# 52   USD_2005·a/t  3608.0000
# 53   USD_2005·a/t  2737.0000
# 54          MWh/t     0.4900
# 55          MWh/t     0.4900
# 56          MWh/t     0.4900
# 57          MWh/t     2.2500
# 58          MWh/t     2.2500
# 59          MWh/t     2.2500
# 60            pct     0.9132
# 61            pct     0.9132
# 62            pct     0.9132
# 63     USD_2005/t   149.3000
# 64     USD_2005/t   149.3000
# 65     USD_2005/t   149.3000
# 66     USD_2005/t   149.3000
# 67     USD_2005/t   149.3000
# 68     USD_2005/t   149.3000
# 69          MWh/t     0.1389
# 70          MWh/t     0.1389
# 71          MWh/t     0.1389
# 72          MWh/t     0.1110
# 73          MWh/t     0.1110
# 74          MWh/t     0.1110
# 75     USD_2005/t     6.0000
# 76     USD_2005/t    10.0000
# 77     USD_2005/t     6.0000
# 78     USD_2005/t    10.0000
# 79     USD_2005/t     6.0000
# 80     USD_2005/t    10.0000
# 81          MWh/t     0.2222
# 82          MWh/t     0.2222
# 83          MWh/t     0.2222
# 84          MWh/t     0.3450
# 85          MWh/t     0.3450
# 86          MWh/t     0.3450
# 87     USD_2005/t    18.0000
# 88     USD_2005/t    33.0000
# 89     USD_2005/t    18.0000
# 90     USD_2005/t    33.0000
# 91     USD_2005/t    18.0000
# 92     USD_2005/t    33.0000
# 93     USD_2005/t     5.0000
# 94     USD_2005/t     7.0000
# 95     USD_2005/t     5.0000
# 96     USD_2005/t     7.0000
# 97     USD_2005/t     5.0000
# 98     USD_2005/t     7.0000
# 99   USD_2005·a/t   530.7000
# 100  USD_2005·a/t   448.9000
# 101  USD_2005·a/t   719.4000
# 102  USD_2005·a/t   678.6000
# 103  USD_2005·a/t   247.6000
# 104  USD_2005·a/t   104.5000
# 105         MWh/t     0.6940
# 106         MWh/t     0.6940
# 107         MWh/t     0.6940
# 108         MWh/t     2.0840
# 109         MWh/t     2.0840
# 110         MWh/t     2.0840
# 111             a    20.0000
# 112             a    20.0000
# 113             a    20.0000
# 114           pct     0.9132
# 115           pct     0.9132
# 116           pct     0.9132
# 117    USD_2005/t    21.2300
# 118    USD_2005/t    28.7800
# 119    USD_2005/t     9.9030
# 120         MWh/t     2.0000
# 121         MWh/t     2.0000
# 122         MWh/t     2.0000
# 123  USD_2005·a/t   308.9000
# 124  USD_2005·a/t   488.3000
# 125  USD_2005·a/t   129.4000
# 126         MWh/t     1.6850
# 127         MWh/t     1.3390
# 128         MWh/t     1.6850
# 129         MWh/t     1.3390
# 130         MWh/t     1.6850
# 131         MWh/t     1.3390
# 132             a    30.0000
# 133             a    25.0000
# 134             a    30.0000
# 135             a    25.0000
# 136             a    30.0000
# 137             a    25.0000
# 138           pct     0.9132
# 139           pct     0.9132
# 140           pct     0.9132
# 141    USD_2005/t    12.3500
# 142    USD_2005/t    19.5300
# 143    USD_2005/t     5.1770
# 144         MWh/t     1.7360
# 145         MWh/t     1.7360
# 146         MWh/t     1.7360
# 147  USD_2005·a/t   200.0000
# 148  USD_2005·a/t  1000.0000
# 149  USD_2005·a/t   200.0000
# 150  USD_2005·a/t  1000.0000
# 151  USD_2005·a/t   200.0000
# 152  USD_2005·a/t  1000.0000
# 153         MWh/t     0.1667
# 154         MWh/t     0.3056
# 155         MWh/t     0.1667
# 156         MWh/t     0.3056
# 157         MWh/t     0.1667
# 158         MWh/t     0.3056
# 159         MWh/t     1.2220
# 160         MWh/t     2.0000
# 161         MWh/t     1.2220
# 162         MWh/t     2.0000
# 163         MWh/t     1.2220
# 164         MWh/t     2.0000
# 165    USD_2005/t    19.0000
# 166    USD_2005/t     9.0000
# 167    USD_2005/t    19.0000
# 168    USD_2005/t     9.0000
# 169    USD_2005/t    19.0000
# 170    USD_2005/t     9.0000
# 171         MWh/t     0.1389
# 172         MWh/t     0.1389
# 173         MWh/t     0.1389
# 174         MWh/t     0.1110
# 175         MWh/t     0.1110
# 176         MWh/t     0.1110
# 177         MWh/t     0.6389
# 178         MWh/t     0.6389
# 179         MWh/t     0.6389
# 180         MWh/t     0.1800
# 181         MWh/t     0.1800
# 182         MWh/t     0.1800

# %%
#NSHADataSet('Tech|MEOH-SYN').select(period=2040)

# %%
TEDF('Tech|HBNH3-ASU').load().check()
DataSet('Tech|HBNH3-ASU').normalise()

# %%
DataSet('Tech|HBNH3-ASU').select(period=2020)

# %%
DataSet('Tech|HBNH3-ASU').aggregate(period=2020)
